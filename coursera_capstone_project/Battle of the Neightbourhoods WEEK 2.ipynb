# %% [markdown]
# # CAPSTONE PROJECT:

# %% [markdown]
# # Table of Contents:
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <font size = 4.5>
#
# 1. <a href="#item1">[Introduction](#introduction)</a>
# 2. <a href="#item2">[Data](#data)</a>
# 3. <a href="#item3">[Methodology](#methodology)</a>
# 4. <a href="#item4">[Results](#analysis)</a>
# 5. <a href="#item5">[Discussion](#results)</a>
# 6. <a href="#item6">[Conclusion](#conclusion)</a>
#
# </font>
# </div>

# %% [markdown]
# ***
# ## 1. Introduction: <a name="introduction"></a>
# ### Where would be the best place to open a South African restaurant in New York?
#
# As a South African, I have not encountered any South African restaurants in New York City (NYC) that features different aspects of South African cooking. This means there is currently a niche in the market. I know a lot of South Africans in New York alone that miss the comfort of home cooking that brings out nostalgia in customers. South African cuisine varies between areas and cultural groups. There are indigenous dishes that have been created since the Khoisan settlers that came from central Africa. However, South Africa (SA) has been influenced by colonial periods where many other nationalities inhabited South Africa including Dutch, English and Indian. The background of South African food is important because with the many cultures included in cooking, different spices and methods are used to prepare the traditional meals.
#
# As the years have progressed, South Africans have immigrated into America at a gradual pace as well as South African tourists, students and workers contributing to the increasing population of South Africans in USA, especially in New York. The diversity of South African cuisine encourages the potential for great success across different ethnic groups. Nando's Chicken and Peri Peri restaurant is one very popular South African restaurant that has been franchised in other African countries, Europe and USA. However, there are no restaurants located in New York City - one of the most culturally diverse cities in the country. There are people who have traveled to Maryland and Virginia in order to buy Nando's. Opening up a Nando's store in NYC will be analysed to see how much of a success it will be not only for the African population living in NYC - but for everyone who enjoys chicken in various forms with a wide variety of sides.
# ***

# %% [markdown]
# ***
# ## 2. Data

# %% [markdown]
# I will be collecting data to answer the following questions:
#
# 1) Are there any South African Restaurants in New York City?
#
# 2) Is there a demand for a South African restaurant in NYC?
#    - Determine if amount of South Africans will be increased by the end of 2020
#
# 3) Where would the best place be to open a Nando's restaurants in NYC?
#    - Looking at how many South Africans reside in NYC
#    - Which borough and neighborhood contain the most South Africans according to history
#    - Projecting the amount of South Africans in NYC in 2020 to illustrate the feasibility of having a Nando's opening in NYC

# %% [markdown]
# #### Loading Libraries:

# %%
import requests
import pandas as pd
import numpy as np 
import random 
# !pip install geocoder==1.5.0
# !pip install folium==0.11.0
# !pip install lxml

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import folium # plotting library
import json
import geocoder

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 


#import beautiful libraries
import urllib.request
import time
from urllib.request import urlopen
import urllib

#for reading files from assets in project folder
import types
from botocore.client import Config
import ibm_boto3

#libraries for methodology
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.linear_model import LinearRegression
import itertools
from matplotlib.ticker import NullFormatter
import matplotlib.ticker as ticker
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
# %matplotlib inline
from scipy import stats
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score
from sklearn import linear_model

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geocoder==1.5.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.5.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder==1.5.0) (2.21.0)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder==1.5.0) (1.12.0)
# Requirement already satisfied: ratelim in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder==1.5.0) (0.1.6)
# Requirement already satisfied: click in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder==1.5.0) (7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder==1.5.0) (2020.6.20)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder==1.5.0) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder==1.5.0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder==1.5.0) (2.8)
# Requirement already satisfied: decorator in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ratelim->geocoder==1.5.0) (4.3.2)
# Requirement already satisfied: folium==0.11.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.11.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium==0.11.0) (1.15.4)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium==0.11.0) (0.4.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium==0.11.0) (2.21.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium==0.11.0) (2.10)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium==0.11.0) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium==0.11.0) (2020.6.20)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium==0.11.0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium==0.11.0) (2.8)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium==0.11.0) (1.1.0)
# Requirement already satisfied: lxml in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.3.1)
# Folium installed
# Libraries imported.

# %% [markdown]
# ### 2.1 Segmenting and Clustering New York City:

# %% [markdown]
# - All information gathered from previous tutorials to create a dataframe segmenting New York neighbourhoods in the boroughs to help visualise data:

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
#using the extracted dat to compile a dataframe 
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
#And make sure that the dataset has all 5 boroughs and 306 neighborhoods.
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 5 boroughs and 306 neighborhoods.

# %% [markdown]
# ### 2.2 I will be exploring any current South African (SA) restaurants in New York City and determining the competition they may oppose, using Foursquare:
#
# - I would like to explore any restaurants in NYC in order to determine the competition level

# %% [markdown]
# - Establishing Foursquare credentials:

# %%
CLIENT_ID = '***' 
CLIENT_SECRET = '***' 
VERSION = '20180604'
LIMIT = 30
print('My credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# My credentials:
# CLIENT_ID: 1CNV51WDL0HVJF1YLVIFT0NI0AK1HBDC2S2T0D4M0UCVINKW
# CLIENT_SECRET:KRXO4PJIWLRWWCZY5JVSRHOJXHHIFRZYEGYOOECCUFEUDSK0

# %% [markdown]
# - Using geopy library to find out and displaying New York City's location:

# %%
address = 'New York, NY'

geolocator = Nominatim(user_agent="new_york_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinate of New York are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinate of New York are 40.7127281, -74.0060152.

# %% [markdown]
# - Creating a search query for South African restaurants in New York City:

# %%
search_query = 'South African'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# South African .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=1CNV51WDL0HVJF1YLVIFT0NI0AK1HBDC2S2T0D4M0UCVINKW&client_secret=KRXO4PJIWLRWWCZY5JVSRHOJXHHIFRZYEGYOOECCUFEUDSK0&ll=40.7127281,-74.0060152&v=20180604&query=South African&radius=1000&limit=30'

# %%
sa_restaurant_results = requests.get(url).json()

# %% [markdown]
# - Extracts results into a dataframe:

# %%
sa_restaurant_df = json_normalize(sa_restaurant_results['response']['venues'])

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in sa_restaurant_df.columns if col.startswith('location.')] + ['id']
dataframe_filtered = sa_restaurant_df.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                name  \
# 0                              South Street Seaport
# 1           African Burial Ground National Monument
# 2                          9/11 Memorial South Pool
# 3                                   South Cove Park
# 4                East River Esplanade South Dog Run
# 5                                Lecture Hall South
# 6           South Street Seaport - Skyline Bus Tour
# 7                   Wok Wok Southeast Asian Kitchen
# 8                         South Street Seaport Mall
# 9   New York Water Taxi - Pier 16, South St Seaport
# 10                        South Street Seaport Rink
# 11                                     South Meadow
# 12                      South Street Seaport Museum
# 13                                     South Marina
# 14         MTA Subway - Fulton St (A/C/J/Z/2/3/4/5)
# 15                        South St Seaport Dog Park
# 16                                     South street
# 17                       South Street Local Artists
# 18             South Street Seaport Open Air Cinema
# 19                           South Food Truck Court
# 20                                 South End Avenue
# 21                              South Cove Cleaners
# 22    South St. Seaport Fresh Market (Sundays Only)
# 23                                South St Heliport
# 24                        TKTS South Street Seaport
# 25                                          Pier 17
# 26                                   South Carolina
# 27                    Southbridge Towers Building 2
# 28                              South Pine Builders
# 29            Southbridge Towers - Basketball Court
#
#                                   categories                         address  \
# 0                            Harbor / Marina                        South St
# 1                        Monument / Landmark                    290 Broadway
# 2                              Memorial Site                         West St
# 3                                      Plaza                   50 Battery Pl
# 4                                    Dog Run                        South St
# 5                          College Classroom                      1 Pace Plz
# 6                                   Bus Line                             NaN
# 7                           Malay Restaurant                      11 Mott St
# 8                              Shopping Mall                    19 Fulton St
# 9                              Boat or Ferry                     89 South St
# 10                              Skating Rink                             NaN
# 11                                      Park                             NaN
# 12                            History Museum                    12 Fulton St
# 13                           Harbor / Marina                             NaN
# 14                             Metro Station                       Fulton St
# 15                                   Dog Run                    South St 124
# 16                              Neighborhood                             NaN
# 17                                 Gift Shop                     93 South St
# 18                             Movie Theater                             NaN
# 19                                Food Truck                             NaN
# 20                                      Road                             NaN
# 21                           Laundry Service                             NaN
# 22                               Flea Market                    108 South St
# 23                                  Heliport                             NaN
# 24                     General Entertainment  Fulton Street and South Street
# 25                                      Pier                     89 South St
# 26                                      None                             NaN
# 27  Residential Building (Apartment / Condo)                    77 Fulton St
# 28                Construction & Landscaping                      PO Box 186
# 29                          Basketball Court                             NaN
#
#     cc      city        country              crossStreet  distance  \
# 0   US  New York  United States                  Pier 17       678
# 1   US  New York  United States                      NaN       255
# 2   US  New York  United States            at Liberty St       625
# 3   US  New York  United States         btw 1st & 3rd Pl      1194
# 4   US  New York  United States                  Wall St       921
# 5   US  New York  United States    btwn Nassau & Gold St       157
# 6   US  New York  United States           South & Fulton       787
# 7   US  New York  United States                      NaN       623
# 8   US  New York  United States              at Water St       668
# 9   US  New York  United States                  Pier 16       917
# 10  US  New York  United States                      NaN       670
# 11  US  New York  United States                      NaN      1000
# 12  US  New York  United States  btwn Water and South St       644
# 13  US  New York  United States                      NaN       903
# 14  US  New York  United States                Nassau St       353
# 15  US  New York  United States      Pine St and Wall St       889
# 16  US       NaN  United States                      NaN       929
# 17  US  New York  United States               Fulton St.       756
# 18  US  New York  United States                      NaN       664
# 19  US  New York  United States                  Liberty       808
# 20  US  New York  United States                      NaN       867
# 21  US       NaN  United States                      NaN      1087
# 22  US  New York  United States                  Beekman       774
# 23  US  New York  United States                      NaN      1187
# 24  US  New York  United States                      NaN       706
# 25  US  New York  United States             at Fulton St       876
# 26  US  New York  United States                      NaN       952
# 27  US  New York  United States                 Gold St.       433
# 28  US   Roberts  United States                      NaN      1086
# 29  US       NaN  United States                      NaN       342
#
#                                      formattedAddress  \
# 0   [South St (Pier 17), New York, NY 10038, Unite...
# 1   [290 Broadway, New York, NY 10007, United States]
# 2   [West St (at Liberty St), New York, NY 10007, ...
# 3   [50 Battery Pl (btw 1st & 3rd Pl), New York, N...
# 4   [South St (Wall St), New York, NY 10038, Unite...
# 5   [1 Pace Plz (btwn Nassau & Gold St), New York,...
# 6       [South & Fulton, New York, NY, United States]
# 7     [11 Mott St, New York, NY 10013, United States]
# 8   [19 Fulton St (at Water St), New York, NY 1003...
# 9   [89 South St (Pier 16), New York, NY 10038, Un...
# 10                      [New York, NY, United States]
# 11                      [New York, NY, United States]
# 12  [12 Fulton St (btwn Water and South St), New Y...
# 13                [New York, NY 10280, United States]
# 14  [Fulton St (Nassau St), New York, NY 10038, Un...
# 15  [South St 124 (Pine St and Wall St), New York,...
# 16                          [New York, United States]
# 17  [93 South St (Fulton St.), New York, NY 10038,...
# 18                      [New York, NY, United States]
# 19             [Liberty, New York, NY, United States]
# 20                [New York, NY 10006, United States]
# 21                          [New York, United States]
# 22  [108 South St (Beekman), New York, NY 10038, U...
# 23                      [New York, NY, United States]
# 24  [Fulton Street and South Street, New York, NY ...
# 25  [89 South St (at Fulton St), New York, NY 1003...
# 26                      [New York, NY, United States]
# 27  [77 Fulton St (Gold St.), New York, NY 10038, ...
# 28     [PO Box 186, Roberts, WI 54023, United States]
# 29                          [New York, United States]
#
#                                        labeledLatLngs        lat        lng  \
# 0                                                 NaN  40.706896 -74.003671
# 1   [{'label': 'display', 'lat': 40.71498975306652...  40.714990 -74.005530
# 2   [{'label': 'display', 'lat': 40.711039, 'lng':...  40.711039 -74.013082
# 3   [{'label': 'display', 'lat': 40.7072926419875,...  40.707293 -74.018223
# 4   [{'label': 'display', 'lat': 40.70445304662184...  40.704453 -74.005814
# 5   [{'label': 'display', 'lat': 40.71135707966446...  40.711357 -74.005550
# 6   [{'label': 'display', 'lat': 40.70602646, 'lng...  40.706026 -74.003021
# 7   [{'label': 'display', 'lat': 40.71405586781807...  40.714056 -73.998839
# 8   [{'label': 'display', 'lat': 40.70695926434493...  40.706959 -74.003798
# 9   [{'label': 'display', 'lat': 40.70501592631589...  40.705016 -74.002191
# 10  [{'label': 'display', 'lat': 40.70693857114326...  40.706939 -74.003830
# 11  [{'label': 'display', 'lat': 40.71578917249773...  40.715789 -74.017162
# 12  [{'label': 'display', 'lat': 40.70720445017337...  40.707204 -74.003729
# 13  [{'label': 'display', 'lat': 40.713869, 'lng':...  40.713869 -74.016620
# 14  [{'label': 'display', 'lat': 40.71070586655301...  40.710706 -74.009243
# 15  [{'label': 'display', 'lat': 40.70474845526084...  40.704748 -74.005548
# 16  [{'label': 'display', 'lat': 40.70521924110689...  40.705219 -74.001204
# 17  [{'label': 'entrance', 'lat': 40.706237, 'lng'...  40.706242 -74.003349
# 18  [{'label': 'display', 'lat': 40.70706779475947...  40.707068 -74.003516
# 19  [{'label': 'display', 'lat': 40.711932, 'lng':...  40.711932 -74.015537
# 20  [{'label': 'display', 'lat': 40.7103504032563,...  40.710350 -74.015802
# 21  [{'label': 'display', 'lat': 40.707923, 'lng':...  40.707923 -74.017236
# 22  [{'label': 'display', 'lat': 40.70806763564096...  40.708068 -73.999201
# 23  [{'label': 'display', 'lat': 40.70236551840832...  40.702366 -74.009347
# 24  [{'label': 'display', 'lat': 40.70649928302699...  40.706499 -74.004421
# 25  [{'label': 'display', 'lat': 40.70556287248011...  40.705563 -74.001718
# 26  [{'label': 'display', 'lat': 40.7042565, 'lng'...  40.704256 -74.007590
# 27  [{'label': 'display', 'lat': 40.70922517045361...  40.709225 -74.003763
# 28  [{'label': 'display', 'lat': 40.72106298503115...  40.721063 -73.999310
# 29  [{'label': 'display', 'lat': 40.71045163100789...  40.710452 -74.003287
#
#    postalCode     state                        id
# 0       10038        NY  3fd66200f964a520daf11ee3
# 1       10007        NY  4a9442e3f964a520f92020e3
# 2       10007        NY  587ffcc3ea29b80cdce3468d
# 3       10280        NY  4b8448bbf964a520672c31e3
# 4       10038        NY  4e0a48b46284cf220c358959
# 5       10038        NY  4e9dd2f802d52778064d114b
# 6         NaN        NY  51f9221f8bbd3fa0118328fb
# 7       10013        NY  55b52904498edca26ecc7a7f
# 8       10038        NY  4ddfd7107d8b04e50266d1cf
# 9       10038        NY  4cdae82bb34e60fce7474499
# 10        NaN        NY  529a8582498e26ef5f5e6599
# 11        NaN        NY  51858d4d498edeec0565b4ef
# 12      10038        NY  4ab67030f964a520187720e3
# 13      10280        NY  508ac438e4b07c9fb02e3faf
# 14      10038        NY  4ad78220f964a520960b21e3
# 15      10005        NY  4e11f28ed1647a0fff851926
# 16        NaN  New York  4ca562477334236a3d291658
# 17      10038        NY  545054b5498e651ad8458387
# 18        NaN        NY  537fd466498e54d58e7bb742
# 19        NaN        NY  51e57352498eb9115b270d65
# 20      10006        NY  5025b9dce4b0d9e3eaf97f4c
# 21        NaN  New York  4ba50f39f964a52024d738e3
# 22      10038        NY  4e9b1772f5b9d59004cd2fc1
# 23        NaN        NY  51c5f942498e94fdfab99c9b
# 24      10038        NY  51d720ee50191928a5c104d1
# 25      10038        NY  4baae71df964a520118d3ae3
# 26        NaN        NY  51a78fb5498ef3fe8fad25f1
# 27      10038        NY  4e0072fbc65b896d116a3d69
# 28      54023        WI  5832fd2f7ff1e43c19f44fe4
# 29        NaN  New York  4e70ff0452b140871b7c91a3

# %% [markdown]
# - ##### There are no South African restaurants in New York City area therefore there is a gap in the market for one.

# %% [markdown]
# ### 2.3 Research all Nando's restaurants in USA:

# %% [markdown]
# - Explore all Nando's restaurants in Chicago, using Foursquare:

# %%
address = 'Chicago, United States'

geolocator = Nominatim(user_agent="chicago_explorer")
chicago_location = geolocator.geocode(address)
chicago_latitude = chicago_location.latitude
chicago_longitude = chicago_location.longitude
print('The geographical coordinate of Chicago are {}, {}.'.format(chicago_latitude, chicago_longitude))
# Out:
# The geographical coordinate of Chicago are 41.8755616, -87.6244212.

# %% [markdown]
# - Creates search query for Nando's peri Peri restaurants:

# %%
nandos_search_query = 'Nando\'s Peri Peri'
nandos_radius = 100000
usa_LIMIT = 200
print(nandos_search_query + ' .... OK!')
# Out:
# Nando's Peri Peri .... OK!

# %%
nandos_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, chicago_latitude, chicago_longitude, VERSION, nandos_search_query, nandos_radius, usa_LIMIT)
nandos_url
# Out:
# "https://api.foursquare.com/v2/venues/search?client_id=1CNV51WDL0HVJF1YLVIFT0NI0AK1HBDC2S2T0D4M0UCVINKW&client_secret=KRXO4PJIWLRWWCZY5JVSRHOJXHHIFRZYEGYOOECCUFEUDSK0&ll=41.8755616,-87.6244212&v=20180604&query=Nando's Peri Peri&radius=100000&limit=200"

# %%
nandos_results = requests.get(nandos_url).json()
nandos_results
# Out:
# {'meta': {'code': 200, 'requestId': '5f6f736cc96e3e511e1a45d6'},
#  'response': {'venues': [{'id': '59aed71ed552c7632d13c4ee',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '117 E Lake St',
#      'lat': 41.88569436185178,
#      'lng': -87.624279366855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88569436185178,
#        'lng': -87.624279366855}],
#      'distance': 1128,
#      'postalCode': '60601',
#      'cc': 'US',
#      'neighborhood': 'The Loop',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['117 E Lake St',
#       'Chicago, IL 60601',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '57a77b9ccd10b3ef21d62622',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '227 E Ontario St',
#      'lat': 41.89334608148888,
#      'lng': -87.62160431031906,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89334608148888,
#        'lng': -87.62160431031906}],
#      'distance': 1993,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['227 E Ontario St',
#       'Chicago, IL 60611',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '5652164f498e36174c80c9d5',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '22 S Wabash Ave',
#      'lat': 41.88132517058762,
#      'lng': -87.62610609482775,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88132517058762,
#        'lng': -87.62610609482775},
#       {'label': 'entrance', 'lat': 41.881387, 'lng': -87.626339}],
#      'distance': 656,
#      'postalCode': '60603',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['22 S Wabash Ave',
#       'Chicago, IL 60603',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '57916296498e390c2b6789cd',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '1005 S Delano Ct E',
#      'crossStreet': 'no',
#      'lat': 41.86961552058229,
#      'lng': -87.63266196134563,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.86961552058229,
#        'lng': -87.63266196134563}],
#      'distance': 951,
#      'postalCode': '60605',
#      'cc': 'US',
#      'neighborhood': 'South Loop',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['1005 S Delano Ct E (no)',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '582bcbf3b4f96227bc841dd9',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '523 Oakbrook Ctr',
#      'lat': 41.85196765881677,
#      'lng': -87.95239007893997,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.85196765881677,
#        'lng': -87.95239007893997}],
#      'distance': 27316,
#      'postalCode': '60523',
#      'cc': 'US',
#      'city': 'Oak Brook',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['523 Oakbrook Ctr',
#       'Oak Brook, IL 60523',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '5879756edebdf66d8d988415',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '1447 E 53rd St',
#      'lat': 41.79939796688211,
#      'lng': -87.5899214131085,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.79939796688211,
#        'lng': -87.5899214131085}],
#      'distance': 8948,
#      'postalCode': '60615',
#      'cc': 'US',
#      'neighborhood': 'Hyde Park',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['1447 E 53rd St',
#       'Chicago, IL 60615',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '5723f8cd498e225a55db86e4',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '1138 Lake St',
#      'lat': 41.888682483710646,
#      'lng': -87.80428429979423,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.888682483710646,
#        'lng': -87.80428429979423},
#       {'label': 'entrance', 'lat': 41.888709, 'lng': -87.804373}],
#      'distance': 14978,
#      'postalCode': '60301',
#      'cc': 'US',
#      'city': 'Oak Park',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['1138 Lake St',
#       'Oak Park, IL 60301',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '56082509498e965f8c47da3c',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '1500 N Clybourn Ave',
#      'lat': 41.90864069497578,
#      'lng': -87.64734411347325,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.90864069497578,
#        'lng': -87.64734411347325}],
#      'distance': 4143,
#      'postalCode': '60610',
#      'cc': 'US',
#      'neighborhood': 'Near North',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['1500 N Clybourn Ave',
#       'Chicago, IL 60610',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '582b45bb0839692c503a3a02',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '4999 Old Orchard Ctr',
#      'lat': 42.06106950200311,
#      'lng': -87.75003986711931,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.06106950200311,
#        'lng': -87.75003986711931}],
#      'distance': 23120,
#      'postalCode': '60077',
#      'cc': 'US',
#      'city': 'Skokie',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['4999 Old Orchard Ctr',
#       'Skokie, IL 60077',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '56edd744cd10c4efe37e197f',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '6 W Jefferson Ave',
#      'lat': 41.77284854418508,
#      'lng': -88.14809982662725,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.77284854418508,
#        'lng': -88.14809982662725}],
#      'distance': 44920,
#      'postalCode': '60540',
#      'cc': 'US',
#      'city': 'Naperville',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['6 W Jefferson Ave',
#       'Naperville, IL 60540',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '55578ce6498e5067c3f53ffd',
#     'name': "Nando's",
#     'location': {'address': '953 W Randolph St',
#      'crossStreet': 'at N Morgan St',
#      'lat': 41.88414549439909,
#      'lng': -87.65179925898083,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88414549439909,
#        'lng': -87.65179925898083}],
#      'distance': 2462,
#      'postalCode': '60607',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['953 W Randolph St (at N Morgan St)',
#       'Chicago, IL 60607',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '558708ac498ebcd400e0e291',
#     'name': "Nando's",
#     'location': {'address': '670 W Diversey Pkwy',
#      'crossStreet': 'Clark',
#      'lat': 41.932837809051634,
#      'lng': -87.64634315669313,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.932837809051634,
#        'lng': -87.64634315669313}],
#      'distance': 6629,
#      'postalCode': '60614',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['670 W Diversey Pkwy (Clark)',
#       'Chicago, IL 60614',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '5c9e7614fb8e59002cd0399e',
#     'name': "Porto's Peri Peri",
#     'location': {'address': '1419 W Taylor St',
#      'lat': 41.869089,
#      'lng': -87.662475,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.869089,
#        'lng': -87.662475}],
#      'distance': 3235,
#      'postalCode': '60607',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['1419 W Taylor St',
#       'Chicago, IL 60607',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1060731',
#      'url': 'https://www.grubhub.com/restaurant/port-of-peri-peri-1419-w-taylor-st-chicago/1060731?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1060731',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '53fa2b6d498ea78067dfd167',
#     'name': "Porto's Peri Peri",
#     'location': {'address': '4915 Oakton St',
#      'lat': 42.026260107551295,
#      'lng': -87.75069803536329,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 42.026260107551295,
#        'lng': -87.75069803536329},
#       {'label': 'entrance', 'lat': 42.026193, 'lng': -87.750722}],
#      'distance': 19766,
#      'postalCode': '60077',
#      'cc': 'US',
#      'city': 'Skokie',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['4915 Oakton St',
#       'Skokie, IL 60077',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1255817',
#      'url': 'https://www.grubhub.com/restaurant/portos-peri-peri-4915-oakton-st-skokie/1255817?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1255817',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4dbeeb68cda109aa6cd5227e',
#     'name': 'Periodontics Llc',
#     'location': {'address': '25 E Madison St',
#      'crossStreet': 'State',
#      'lat': 41.881822,
#      'lng': -87.626694,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.881822,
#        'lng': -87.626694},
#       {'label': 'entrance', 'lat': 41.881907, 'lng': -87.626809}],
#      'distance': 721,
#      'postalCode': '60602',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['25 E Madison St (State)',
#       'Chicago, IL 60602',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '5c080d5c28374e002c89c00d',
#     'name': 'Love Peridot',
#     'location': {'address': '1114 S Delano Ct W',
#      'crossStreet': 'Roosevelt',
#      'lat': 41.868803,
#      'lng': -87.632639,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.868803,
#        'lng': -87.632639}],
#      'distance': 1014,
#      'postalCode': '60605',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['1114 S Delano Ct W (Roosevelt)',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d102951735',
#       'name': 'Accessories Store',
#       'pluralName': 'Accessories Stores',
#       'shortName': 'Accessories',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_accessories_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4bbcca4a8ec3d13a923c1b28',
#     'name': 'Millennium Periodontics',
#     'location': {'address': '223 W Jackson Blvd',
#      'crossStreet': 'Franklin',
#      'lat': 41.877876,
#      'lng': -87.634784,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.877876,
#        'lng': -87.634784},
#       {'label': 'entrance', 'lat': 41.878016, 'lng': -87.634681}],
#      'distance': 896,
#      'postalCode': '60606',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['223 W Jackson Blvd (Franklin)',
#       'Chicago, IL 60606',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '39854941'},
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '511a6acb759629b50618cbdd',
#     'name': 'Perillo BMW, Inc.',
#     'location': {'address': '1035 N Clark St',
#      'lat': 41.901642295912005,
#      'lng': -87.63096402027941,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.901642295912005,
#        'lng': -87.63096402027941},
#       {'label': 'entrance', 'lat': 41.901555, 'lng': -87.631221}],
#      'distance': 2953,
#      'postalCode': '60610',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['1035 N Clark St',
#       'Chicago, IL 60610',
#       'United States']},
#     'categories': [{'id': '4eb1c1623b7b52c0e1adc2ec',
#       'name': 'Auto Dealership',
#       'pluralName': 'Auto Dealerships',
#       'shortName': 'Auto Dealer',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '575270155'},
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '53865ff5498ea4ed73caa8ed',
#     'name': 'Perico',
#     'location': {'lat': 41.886145,
#      'lng': -87.612346,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.886145,
#        'lng': -87.612346}],
#      'distance': 1545,
#      'cc': 'US',
#      'state': 'Illinois',
#      'country': 'United States',
#      'formattedAddress': ['Illinois', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12d951735',
#       'name': 'Boat or Ferry',
#       'pluralName': 'Boats or Ferries',
#       'shortName': 'Boat / Ferry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/boat_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4bdd8d7fea279c744142e22b',
#     'name': 'Perimeter Gallery',
#     'location': {'address': '210 W Superior St',
#      'lat': 41.89556871468464,
#      'lng': -87.63478722153226,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89556871468464,
#        'lng': -87.63478722153226},
#       {'label': 'entrance', 'lat': 41.895689, 'lng': -87.634834}],
#      'distance': 2387,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['210 W Superior St',
#       'Chicago, IL 60654',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '53976f3d498ecd116270840d',
#     'name': 'perimeter advisors',
#     'location': {'lat': 41.89070963690098,
#      'lng': -87.62654578840348,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89070963690098,
#        'lng': -87.62654578840348}],
#      'distance': 1695,
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['Chicago, IL', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '50db16fbe4b0487c51fbbe17',
#     'name': 'Peritius Consulting',
#     'location': {'address': '560 W Washington Blvd Ste 330',
#      'lat': 41.883355384678474,
#      'lng': -87.64288743864203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.883355384678474,
#        'lng': -87.64288743864203},
#       {'label': 'entrance', 'lat': 41.883284, 'lng': -87.64208}],
#      'distance': 1759,
#      'postalCode': '60661',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['560 W Washington Blvd Ste 330',
#       'Chicago, IL 60661',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '5d33a915e2efbf0008acb0e4',
#     'name': 'Perilla',
#     'location': {'address': '401 N Milwaukee Ave',
#      'lat': 41.889346,
#      'lng': -87.644666,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.889346,
#        'lng': -87.644666}],
#      'distance': 2273,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['401 N Milwaukee Ave',
#       'Chicago, IL 60654',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4d5da3dfd4fca143691dd909',
#     'name': 'Perillo Service',
#     'location': {'address': '530 W Chicago Ave',
#      'lat': 41.89659124583866,
#      'lng': -87.64240264892577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89659124583866,
#        'lng': -87.64240264892577}],
#      'distance': 2775,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['530 W Chicago Ave',
#       'Chicago, IL 60654',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'shortName': 'Automotive',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '57927d64498ec2d314f60458',
#     'name': 'Perillo Motors',
#     'location': {'address': '681 N Green St',
#      'lat': 41.89485,
#      'lng': -87.64830699999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89485,
#        'lng': -87.64830699999999},
#       {'label': 'entrance', 'lat': 41.894726, 'lng': -87.648762}],
#      'distance': 2920,
#      'postalCode': '60642',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['681 N Green St',
#       'Chicago, IL 60642',
#       'United States']},
#     'categories': [{'id': '56aa371be4b08b9a8d5734d3',
#       'name': 'Auto Workshop',
#       'pluralName': 'Auto Workshops',
#       'shortName': 'Auto Workshop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4e67e530b3ad5d91974220ee',
#     'name': 'Perillo Exotic Cars',
#     'location': {'address': '834 N Rush St',
#      'crossStreet': 'Pearson',
#      'lat': 41.897919,
#      'lng': -87.626531,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.897919,
#        'lng': -87.626531},
#       {'label': 'entrance', 'lat': 41.897663, 'lng': -87.626312}],
#      'distance': 2494,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['834 N Rush St (Pearson)',
#       'Chicago, IL 60611',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'shortName': 'Automotive',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4b8fbfb9f964a5203c6033e3',
#     'name': 'Periodontal Associates',
#     'location': {'address': '845 N Michigan Ave Ste 940W',
#      'lat': 41.898002000000005,
#      'lng': -87.622914,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.898002000000005,
#        'lng': -87.622914}],
#      'distance': 2501,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['845 N Michigan Ave Ste 940W',
#       'Chicago, IL 60611',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4e0cec41aeb7a5b33edb1d47',
#     'name': 'Perillo Rolls Royce',
#     'location': {'address': '824 N Rush St',
#      'lat': 41.89762307062992,
#      'lng': -87.62581314463756,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89762307062992,
#        'lng': -87.62581314463756}],
#      'distance': 2458,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['824 N Rush St',
#       'Chicago, IL 60611',
#       'United States']},
#     'categories': [{'id': '4eb1c1623b7b52c0e1adc2ec',
#       'name': 'Auto Dealership',
#       'pluralName': 'Auto Dealerships',
#       'shortName': 'Auto Dealer',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4e26da1c62e14d5da15250f6',
#     'name': 'Perillo Pre-Owned Outlet',
#     'location': {'address': '530 W Chicago Ave',
#      'lat': 41.897159,
#      'lng': -87.642463,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.897159,
#        'lng': -87.642463}],
#      'distance': 2831,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['530 W Chicago Ave',
#       'Chicago, IL 60654',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'shortName': 'Automotive',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '5050c35e64a41e458b449caf',
#     'name': 'Perillo Collision Center',
#     'location': {'address': '681 N Green St',
#      'crossStreet': 'Btw Maple & Oak',
#      'lat': 41.8948279,
#      'lng': -87.648073,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.8948279,
#        'lng': -87.648073}],
#      'distance': 2905,
#      'postalCode': '60642',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['681 N Green St (Btw Maple & Oak)',
#       'Chicago, IL 60642',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'shortName': 'Automotive',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '5c9e121ed03360002cb32100',
#     'name': 'Perioni Inc',
#     'location': {'address': '2150 S Canalport Ave',
#      'lat': 41.853805982476416,
#      'lng': -87.64842179418224,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.853805982476416,
#        'lng': -87.64842179418224}],
#      'distance': 3134,
#      'postalCode': '60608',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['2150 S Canalport Ave',
#       'Chicago, IL 60608',
#       'United States']},
#     'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#       'name': 'Market',
#       'pluralName': 'Markets',
#       'shortName': 'Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '581e14b249e90070d4195c1e',
#     'name': 'Loop Perio',
#     'location': {'address': '25 E Washington St Ste 2033',
#      'lat': 41.85099076040331,
#      'lng': -87.6498806476593,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.85099076040331,
#        'lng': -87.6498806476593}],
#      'distance': 3454,
#      'postalCode': '60602',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['25 E Washington St Ste 2033',
#       'Chicago, IL 60602',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4c82ae1d74d7b60cf5f782d8',
#     'name': "Perillo's",
#     'location': {'lat': 41.859348,
#      'lng': -87.663606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.859348,
#        'lng': -87.663606}],
#      'distance': 3716,
#      'postalCode': '60608',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['Chicago, IL 60608', 'United States']},
#     'categories': [],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '5210c9bc11d266f80cef3af4',
#     'name': 'Nick Perisin - State Farm Insurance Agent',
#     'location': {'address': '725 W 31st St',
#      'lat': 41.83787428488652,
#      'lng': -87.64491028156044,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.83787428488652,
#        'lng': -87.64491028156044},
#       {'label': 'entrance', 'lat': 41.83797, 'lng': -87.644889}],
#      'distance': 4526,
#      'postalCode': '60616',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['725 W 31st St',
#       'Chicago, IL 60616',
#       'United States']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1f1',
#       'name': 'Insurance Office',
#       'pluralName': 'Insurance Offices',
#       'shortName': 'Insurance Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '54b4c984498eb25a341db629',
#     'name': 'Perimeter Architects',
#     'location': {'address': '1732 W Hubbard St #1B',
#      'lat': 41.890064,
#      'lng': -87.671005,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.890064,
#        'lng': -87.671005}],
#      'distance': 4184,
#      'postalCode': '60622',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['1732 W Hubbard St #1B',
#       'Chicago, IL 60622',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '547d509b498ed31e7b008365',
#     'name': 'Implant Dentist & Periodontist (Dr. Tolga Tozum)',
#     'location': {'address': '801 S Paulina St Rm 331',
#      'lat': 41.87087631225586,
#      'lng': -87.66886138916016,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87087631225586,
#        'lng': -87.66886138916016}],
#      'distance': 3720,
#      'postalCode': '60612',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['801 S Paulina St Rm 331',
#       'Chicago, IL 60612',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4c7fdf28d8086dcba0a35e52',
#     'name': 'American Academy of Periodontology',
#     'location': {'address': '737 N Michigan Ave',
#      'crossStreet': 'Chicago Ave',
#      'lat': 41.89655473091874,
#      'lng': -87.6232281403554,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89655473091874,
#        'lng': -87.6232281403554},
#       {'label': 'entrance', 'lat': 41.89606, 'lng': -87.624015}],
#      'distance': 2339,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['737 N Michigan Ave (Chicago Ave)',
#       'Chicago, IL 60611',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4b1fd404f964a5207d2924e3',
#     'name': 'UIC College of Dentistry, Periodontics',
#     'location': {'address': '801 S Paulina St',
#      'crossStreet': 'Polk & Paulina',
#      'lat': 41.87148627164138,
#      'lng': -87.66842042938204,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87148627164138,
#        'lng': -87.66842042938204}],
#      'distance': 3675,
#      'postalCode': '60612',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['801 S Paulina St (Polk & Paulina)',
#       'Chicago, IL 60612',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4dc0657043a147cd6ed833f4',
#     'name': 'Charles Goodman Periodontist',
#     'location': {'address': '2835 N Sheffield Ave Ste 408',
#      'lat': 41.9338,
#      'lng': -87.65354,
#      'labeledLatLngs': [{'label': 'display', 'lat': 41.9338, 'lng': -87.65354},
#       {'label': 'entrance', 'lat': 41.933892, 'lng': -87.653779}],
#      'distance': 6917,
#      'postalCode': '60657',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['2835 N Sheffield Ave Ste 408',
#       'Chicago, IL 60657',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4d6c7ce37f1c548173106a52',
#     'name': 'Periwinkle',
#     'location': {'address': '2320 superior street',
#      'crossStreet': 'Oakley',
#      'lat': 41.8951011,
#      'lng': -87.684387,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.8951011,
#        'lng': -87.684387}],
#      'distance': 5424,
#      'cc': 'US',
#      'state': 'Illinois',
#      'country': 'United States',
#      'formattedAddress': ['2320 superior street (Oakley)',
#       'Illinois',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '5e645fd4a78d270008637bee',
#     'name': 'Halal Peri Peri Chicken & Grill',
#     'location': {'lat': 41.997812,
#      'lng': -87.689354,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.997812,
#        'lng': -87.689354}],
#      'distance': 14632,
#      'postalCode': '60659',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['Chicago, IL 60659', 'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1937452',
#      'url': 'https://www.grubhub.com/restaurant/halal-peri-peri-2350-w-devon-ave-chicago/1937452?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1937452',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4b6188b9f964a52023172ae3',
#     'name': 'Perillo Mercury, Lincoln & Saab',
#     'location': {'address': '1111 W Diversey Pkwy',
#      'crossStreet': 'b/t Diversey School Ct & Seminary Ave',
#      'lat': 41.932301,
#      'lng': -87.656272,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.932301,
#        'lng': -87.656272}],
#      'distance': 6845,
#      'postalCode': '60614',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['1111 W Diversey Pkwy (b/t Diversey School Ct & Seminary Ave)',
#       'Chicago, IL 60614',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'shortName': 'Automotive',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4e46afe3fa76a07fde5cd1b2',
#     'name': 'Barbacoa El Perico',
#     'location': {'address': '4248 S Ashland Ave',
#      'lat': 41.816226959228516,
#      'lng': -87.6655044555664,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 41.81627,
#        'lng': -87.665343},
#       {'label': 'display',
#        'lat': 41.816226959228516,
#        'lng': -87.6655044555664}],
#      'distance': 7431,
#      'postalCode': '60609',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['4248 S Ashland Ave',
#       'Chicago, IL 60609',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '529e638d11d2e6ac9d171996',
#     'name': 'Periscope Post & Audio',
#     'location': {'address': '2602 W 16th St',
#      'lat': 41.859567999999996,
#      'lng': -87.691022,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.859567999999996,
#        'lng': -87.691022}],
#      'distance': 5801,
#      'postalCode': '60608',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['2602 W 16th St',
#       'Chicago, IL 60608',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f4941735',
#       'name': 'Design Studio',
#       'pluralName': 'Design Studios',
#       'shortName': 'Design',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/design_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4ddef69cfa76b3b015f56a12',
#     'name': 'Velvet Perineum',
#     'location': {'address': '2125 N Milwaukee Ave',
#      'lat': 41.920313,
#      'lng': -87.692215,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.920313,
#        'lng': -87.692215},
#       {'label': 'entrance', 'lat': 41.919902, 'lng': -87.692231}],
#      'distance': 7508,
#      'postalCode': '60647',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['2125 N Milwaukee Ave',
#       'Chicago, IL 60647',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e9931735',
#       'name': 'Rock Club',
#       'pluralName': 'Rock Clubs',
#       'shortName': 'Rock Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_rockclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4dddc5a9d164154218359133',
#     'name': 'Velvet Perineum',
#     'location': {'address': '2515 N Milwaukee Ave',
#      'lat': 41.927237,
#      'lng': -87.70388299999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.927237,
#        'lng': -87.70388299999999}],
#      'distance': 8742,
#      'postalCode': '60647',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['2515 N Milwaukee Ave',
#       'Chicago, IL 60647',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e9931735',
#       'name': 'Rock Club',
#       'pluralName': 'Rock Clubs',
#       'shortName': 'Rock Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_rockclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '515723d8e4b03e8de84c81e5',
#     'name': 'Hyde Park Periodontics & Implant Solutions',
#     'location': {'address': '1525 E 53rd St Ste 610',
#      'lat': 41.799336,
#      'lng': -87.588189,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.799336,
#        'lng': -87.588189}],
#      'distance': 9001,
#      'postalCode': '60615',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['1525 E 53rd St Ste 610',
#       'Chicago, IL 60615',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4f32e6a6e4b0dd592a1f6046',
#     'name': 'Perishables Group',
#     'location': {'address': '1700 W Irving Park Rd',
#      'crossStreet': 'Hermitage',
#      'lat': 41.954492,
#      'lng': -87.67141,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.954492,
#        'lng': -87.67141}],
#      'distance': 9610,
#      'postalCode': '60613',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['1700 W Irving Park Rd (Hermitage)',
#       'Chicago, IL 60613',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4ea86e1ac2eea8b0cef6629c',
#     'name': 'Periwinkle Park',
#     'location': {'address': '30 W 66Th St',
#      'lat': 41.77464028786309,
#      'lng': -87.62818694114685,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.77464028786309,
#        'lng': -87.62818694114685}],
#      'distance': 11238,
#      'postalCode': '60621',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['30 W 66Th St',
#       'Chicago, IL 60621',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False},
#    {'id': '4f2d5ed3e4b05a84d7cb72a2',
#     'name': 'Perio Healthcare Center, John Dimoulis DDS, MS',
#     'location': {'lat': 41.986388,
#      'lng': -87.70115,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.986388,
#        'lng': -87.70115}],
#      'distance': 13877,
#      'postalCode': '60659',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['Chicago, IL 60659', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139564',
#     'hasPerk': False}]}}

# %%
'There are {} around Chicago.'.format(len(nandos_results['response']['venues']))
# Out:
# 'There are 50 around Chicago.'

# %% [markdown]
# - Extract search results from Chicago into a dataframe:

# %%
# assign relevant part of JSON to venues
nandos_venues = nandos_results['response']['venues']

# tranform venues into a dataframe
nandos_chicago_df = json_normalize(nandos_venues)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in nandos_chicago_df.columns if col.startswith('location.')] + ['id']
dataframe_filtered1 = nandos_chicago_df.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered1['categories'] = dataframe_filtered1.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered1.columns = [column.split('.')[-1] for column in dataframe_filtered1.columns]

dataframe_filtered1 = dataframe_filtered1[dataframe_filtered1['name'].str.contains('Nando\'s')]
dataframe_filtered1.drop(['crossStreet'], axis = 1,  inplace = True)

# %% [markdown]
# - Explore all Nando's restaurants in Washington DC, Virginia, Maryland area (DMV), using Foursquare:

# %%
#finding washington, DC lattitude and longitude coordinates to  use in foursquare
address = 'Washington,DC'

geolocator = Nominatim(user_agent="dmv_explorer")
dmv_location = geolocator.geocode(address)
dmv_latitude = dmv_location.latitude
dmv_longitude = dmv_location.longitude
print('The geograpical coordinate of Washington, DC are {}, {}.'.format(dmv_latitude, dmv_longitude))
# Out:
# The geograpical coordinate of Washington, DC are 38.8949855, -77.0365708.

# %%
#search all nandoes in Washington area
nandos1_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, dmv_latitude, dmv_longitude, VERSION, nandos_search_query, nandos_radius, usa_LIMIT)
nandos1_url
# Out:
# "https://api.foursquare.com/v2/venues/search?client_id=1CNV51WDL0HVJF1YLVIFT0NI0AK1HBDC2S2T0D4M0UCVINKW&client_secret=KRXO4PJIWLRWWCZY5JVSRHOJXHHIFRZYEGYOOECCUFEUDSK0&ll=38.8949855,-77.0365708&v=20180604&query=Nando's Peri Peri&radius=100000&limit=200"

# %%
nandos1_results = requests.get(nandos1_url).json()
nandos1_results
# Out:
# {'meta': {'code': 200, 'requestId': '5f6f736d86ebb970eae482d5'},
#  'response': {'venues': [{'id': '5106bffae4b0cbc88a16c069',
#     'name': "Nando's PERi-PERi Central Office",
#     'location': {'lat': 38.900403999999995,
#      'lng': -77.02160400000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.900403999999995,
#        'lng': -77.02160400000001},
#       {'label': 'entrance', 'lat': 38.900404, 'lng': -77.021793}],
#      'distance': 1430,
#      'postalCode': '20001',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C. 20001', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139565',
#     'hasPerk': False},
#    {'id': '5aa6ab5c95da0c6a54a0162e',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '1800 N Lynn St, # 100',
#      'lat': 38.896782174196005,
#      'lng': -77.07133957644193,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.896782174196005,
#        'lng': -77.07133957644193}],
#      'distance': 3018,
#      'postalCode': '22209',
#      'cc': 'US',
#      'city': 'Arlington',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1800 N Lynn St, # 100',
#       'Arlington, VA 22209',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '57c61813498e250533871440',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '2631 Connecticut Ave NW',
#      'lat': 38.92448048565016,
#      'lng': -77.05193237470479,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.92448048565016,
#        'lng': -77.05193237470479}],
#      'distance': 3542,
#      'postalCode': '20008',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2631 Connecticut Ave NW',
#       'Washington, D.C. 20008',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '520a756911d20ef0a74a329b',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '300 Tingey St SE, Ste 150',
#      'crossStreet': 'at 4th St SE',
#      'lat': 38.875113778629824,
#      'lng': -77.00117290019988,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.875113778629824,
#        'lng': -77.00117290019988}],
#      'distance': 3781,
#      'postalCode': '20003',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['300 Tingey St SE, Ste 150 (at 4th St SE)',
#       'Washington, D.C. 20003',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '5a0dcecaa5a3153b498f6353',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '12120 Sunset Hills Rd, Ste 103',
#      'lat': 38.954558173100466,
#      'lng': -77.36509186600802,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.954558173100466,
#        'lng': -77.36509186600802}],
#      'distance': 29213,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['12120 Sunset Hills Rd, Ste 103',
#       'Reston, VA 20190',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4e5bbbbf813034cf45e4500d',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '224 Boardwalk Pl',
#      'lat': 39.11672909294069,
#      'lng': -77.19795405799589,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.11672909294069,
#        'lng': -77.19795405799589},
#       {'label': 'entrance', 'lat': 39.116845, 'lng': -77.198249}],
#      'distance': 28358,
#      'postalCode': '20878',
#      'cc': 'US',
#      'city': 'Gaithersburg',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['224 Boardwalk Pl',
#       'Gaithersburg, MD 20878',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '56d1deb7cd10b98f4cbb3c01',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '411 H St NE',
#      'crossStreet': 'btwn 4th & 5th St NE',
#      'lat': 38.900044744974856,
#      'lng': -77.00008660554886,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.900044744974856,
#        'lng': -77.00008660554886},
#       {'label': 'entrance', 'lat': 38.900084, 'lng': -77.000082}],
#      'distance': 3210,
#      'postalCode': '20002',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['411 H St NE (btwn 4th & 5th St NE)',
#       'Washington, D.C. 20002',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '57125a2a498e20f5ec604732',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '2987 District Ave',
#      'lat': 38.86966475388093,
#      'lng': -77.23120038034156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.86966475388093,
#        'lng': -77.23120038034156}],
#      'distance': 17099,
#      'postalCode': '22031',
#      'cc': 'US',
#      'city': 'Fairfax',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['2987 District Ave',
#       'Fairfax, VA 22031',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4f7d3888e4b0f6ec00d81eae',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '1301 S Joyce St, Ste D10',
#      'lat': 38.86310364957474,
#      'lng': -77.06312254071236,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.86310364957474,
#        'lng': -77.06312254071236}],
#      'distance': 4229,
#      'postalCode': '22202',
#      'cc': 'US',
#      'city': 'Arlington',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1301 S Joyce St, Ste D10',
#       'Arlington, VA 22202',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '57ddadef498e917deca47fe7',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '4401 Wilson Blvd',
#      'crossStreet': 'N Glebe Rd',
#      'lat': 38.8801752129954,
#      'lng': -77.11352011743077,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.8801752129954,
#        'lng': -77.11352011743077}],
#      'distance': 6868,
#      'postalCode': '22203',
#      'cc': 'US',
#      'city': 'Arlington',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['4401 Wilson Blvd (N Glebe Rd)',
#       'Arlington, VA 22203',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4e8b424e93ad2e858aba438a',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '191 American Way',
#      'crossStreet': 'Fleet St',
#      'lat': 38.783984591366305,
#      'lng': -77.01504979335205,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.783984591366305,
#        'lng': -77.01504979335205},
#       {'label': 'entrance', 'lat': 38.784067, 'lng': -77.015227}],
#      'distance': 12496,
#      'postalCode': '20745',
#      'cc': 'US',
#      'city': 'Oxon Hill',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['191 American Way (Fleet St)',
#       'Oxon Hill, MD 20745',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '50856fc0e4b0fedebfa0c98a',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '702 King St',
#      'crossStreet': 'btwn N Washington & N Columbus',
#      'lat': 38.805002,
#      'lng': -77.047422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.805002,
#        'lng': -77.047422}],
#      'distance': 10060,
#      'postalCode': '22314',
#      'cc': 'US',
#      'city': 'Alexandria',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['702 King St (btwn N Washington & N Columbus)',
#       'Alexandria, VA 22314',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4eaeeca01081289f77b48f81',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '4839 Bethesda Ave',
#      'lat': 38.98108594463042,
#      'lng': -77.09720402956009,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.98108594463042,
#        'lng': -77.09720402956009}],
#      'distance': 10928,
#      'postalCode': '20814',
#      'cc': 'US',
#      'city': 'Bethesda',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['4839 Bethesda Ave',
#       'Bethesda, MD 20814',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '5ade087f345cbe1ecb452c2b',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '922 Rose Ave',
#      'lat': 39.05093418611199,
#      'lng': -77.11652314290036,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.05093418611199,
#        'lng': -77.11652314290036}],
#      'distance': 18688,
#      'postalCode': '20852',
#      'cc': 'US',
#      'city': 'North Bethesda',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['922 Rose Ave',
#       'North Bethesda, MD 20852',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '562e4dd4498e6542cc35b284',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '7400 Baltimore Ave',
#      'lat': 38.980948977198736,
#      'lng': -76.93802033155141,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.980948977198736,
#        'lng': -76.93802033155141},
#       {'label': 'entrance', 'lat': 38.980977, 'lng': -76.938069}],
#      'distance': 12821,
#      'postalCode': '20740',
#      'cc': 'US',
#      'city': 'College Park',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['7400 Baltimore Ave',
#       'College Park, MD 20740',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '56705d14498efccf86b5645c',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '2002 Annapolis Mall',
#      'lat': 38.98748974676994,
#      'lng': -76.54681770501998,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.98748974676994,
#        'lng': -76.54681770501998}],
#      'distance': 43636,
#      'postalCode': '21401',
#      'cc': 'US',
#      'city': 'Annapolis',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['2002 Annapolis Mall',
#       'Annapolis, MD 21401',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '5679ded7498ecd39eddb0256',
#     'name': "Nando's Peri-Peri",
#     'location': {'address': '11160 Veirs Mill Rd',
#      'lat': 39.035973427809786,
#      'lng': -77.05493133030606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.035973427809786,
#        'lng': -77.05493133030606}],
#      'distance': 15774,
#      'postalCode': '20902',
#      'cc': 'US',
#      'city': 'Wheaton',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['11160 Veirs Mill Rd',
#       'Wheaton, MD 20902',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4ac6d815f964a52072b620e3',
#     'name': "Nando's",
#     'location': {'address': '1210 18th Street',
#      'crossStreet': 'at Connecticut Ave NW',
#      'lat': 38.90613554456633,
#      'lng': -77.0419505238533,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90613554456633,
#        'lng': -77.0419505238533},
#       {'label': 'entrance', 'lat': 38.906156, 'lng': -77.041842}],
#      'distance': 1325,
#      'postalCode': '20001',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1210 18th Street (at Connecticut Ave NW)',
#       'Washington, D.C. 20001',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4a4eb693f964a520f4ae1fe3',
#     'name': "Nando's",
#     'location': {'address': '819 7th St NW',
#      'crossStreet': 'at I St NW',
#      'lat': 38.90037043531736,
#      'lng': -77.02194153094578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90037043531736,
#        'lng': -77.02194153094578}],
#      'distance': 1402,
#      'postalCode': '20001',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['819 7th St NW (at I St NW)',
#       'Washington, D.C. 20001',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '536c11ed498e87758c93ae2c',
#     'name': "Nando's",
#     'location': {'address': '4231 Wisconsin Ave NW',
#      'crossStreet': 'at Veazey St NW',
#      'lat': 38.944100456836274,
#      'lng': -77.07729399204253,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.944100456836274,
#        'lng': -77.07729399204253}],
#      'distance': 6506,
#      'postalCode': '20016',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['4231 Wisconsin Ave NW (at Veazey St NW)',
#       'Washington, D.C. 20016',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '5d36a728c2424b00082626bc',
#     'name': 'DC Perio and Implants, PLLC',
#     'location': {'address': '1712 I St NW Ste 202',
#      'lat': 38.89958342598271,
#      'lng': -77.03843817114829,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89958342598271,
#        'lng': -77.03843817114829}],
#      'distance': 536,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1712 I St NW Ste 202',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4c8ece09d2aea0933fa1d169',
#     'name': "Nando's",
#     'location': {'address': '924 Ellsworth Dr',
#      'lat': 38.99587221554965,
#      'lng': -77.02653262027613,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.99587221554965,
#        'lng': -77.02653262027613}],
#      'distance': 11264,
#      'postalCode': '20910',
#      'cc': 'US',
#      'city': 'Silver Spring',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['924 Ellsworth Dr',
#       'Silver Spring, MD 20910',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '5bb309a3c0af57002c5e6ac6',
#     'name': 'Perio Implant',
#     'location': {'address': '1212 New York Ave NW #425A',
#      'lat': 38.90012,
#      'lng': -77.02876,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90012,
#        'lng': -77.02876}],
#      'distance': 885,
#      'postalCode': '20005',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1212 New York Ave NW #425A',
#       'Washington, D.C. 20005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '51b9b133498ee45c4604ff03',
#     'name': 'Steven Kaufman, Periodontics & Implantology',
#     'location': {'address': '1145 19th Street, NW, Suite 707',
#      'lat': 38.90505280577517,
#      'lng': -77.04308012931445,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90505280577517,
#        'lng': -77.04308012931445}],
#      'distance': 1254,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1145 19th Street, NW, Suite 707',
#       'Washington, D.C.',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '546788cf498e655a9214e831',
#     'name': "Nando's",
#     'location': {'address': '6500 Springfield Mall',
#      'lat': 38.774142532846575,
#      'lng': -77.17588119363226,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.774142532846575,
#        'lng': -77.17588119363226}],
#      'distance': 18079,
#      'postalCode': '22150',
#      'cc': 'US',
#      'city': 'Springfield',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['6500 Springfield Mall',
#       'Springfield, VA 22150',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '578c4a71498e14e13cbed1b4',
#     'name': 'Precision Periodontics and Implant Dentistry',
#     'location': {'address': '2311 M Street NW',
#      'lat': 38.90548562,
#      'lng': -77.05067335,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90548562,
#        'lng': -77.05067335}],
#      'distance': 1690,
#      'postalCode': '20037',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2311 M Street NW',
#       'Washington, D.C. 20037',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '402156408'},
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '5765b510cd101651ceae2549',
#     'name': 'Newspaper and Current Periodical Room',
#     'location': {'lat': 38.887144,
#      'lng': -77.003577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.887144,
#        'lng': -77.003577}],
#      'distance': 2989,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C.', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4c6bdcec9669e21ed3d4ab51',
#     'name': 'House periodical gallery',
#     'location': {'address': 'The Capitol - Room 304 house side',
#      'lat': 38.888428364708645,
#      'lng': -77.00924050259233,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.888428364708645,
#        'lng': -77.00924050259233}],
#      'distance': 2477,
#      'postalCode': '20001',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['The Capitol - Room 304 house side',
#       'Washington, D.C. 20001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12a941735',
#       'name': 'Capitol Building',
#       'pluralName': 'Capitol Buildings',
#       'shortName': 'Capitol Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_capitolbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4e81e02b93ad73ad7deef1a1',
#     'name': 'Periwinkle',
#     'location': {'lat': 38.8708519,
#      'lng': -77.0463009,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.8708519,
#        'lng': -77.0463009}],
#      'distance': 2815,
#      'cc': 'US',
#      'city': 'Arlington',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['Arlington, VA', 'United States']},
#     'categories': [],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '573f4a71498e31bc63fa9249',
#     'name': 'Peridontics & Implant Dentistry',
#     'location': {'lat': 38.884647,
#      'lng': -77.09201,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.884647,
#        'lng': -77.09201}],
#      'distance': 4939,
#      'cc': 'US',
#      'city': 'Arlington',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['Arlington, VA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '50f0da23e4b050bf8d66de12',
#     'name': 'PerIndia',
#     'location': {'lat': 38.848262,
#      'lng': -77.072649,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.848262,
#        'lng': -77.072649}],
#      'distance': 6068,
#      'postalCode': '22206',
#      'cc': 'US',
#      'city': 'Arlington',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['Arlington, VA 22206', 'United States']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4bd5db847b1876b09c808b86',
#     'name': 'Periwinkle',
#     'location': {'address': '4150 Campbell Ave',
#      'crossStreet': 'The Village at Shirlington',
#      'lat': 38.84079360961914,
#      'lng': -77.08955383300781,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 38.840828,
#        'lng': -77.089669},
#       {'label': 'display',
#        'lat': 38.84079360961914,
#        'lng': -77.08955383300781}],
#      'distance': 7581,
#      'postalCode': '22206',
#      'cc': 'US',
#      'city': 'Arlington',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['4150 Campbell Ave (The Village at Shirlington)',
#       'Arlington, VA 22206',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '54efb873498ed9a991629190',
#     'name': 'Residence of the Ambassador of Peru',
#     'location': {'lat': 38.95653,
#      'lng': -77.060671,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.95653,
#        'lng': -77.060671}],
#      'distance': 7161,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C.', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4b84091af964a520731c31e3',
#     'name': 'Periwinkle',
#     'location': {'address': '3815 Livingston St NW',
#      'lat': 38.963303,
#      'lng': -77.075296,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.963303,
#        'lng': -77.075296},
#       {'label': 'entrance', 'lat': 38.96322, 'lng': -77.075282}],
#      'distance': 8311,
#      'postalCode': '20015',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['3815 Livingston St NW',
#       'Washington, D.C. 20015',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4b708711f964a520f21f2de3',
#     'name': 'Periwinkle',
#     'location': {'address': '1557 Potomac Greens Dr',
#      'lat': 38.821737,
#      'lng': -77.047175,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.821737,
#        'lng': -77.047175},
#       {'label': 'entrance', 'lat': 38.821778, 'lng': -77.047323}],
#      'distance': 8205,
#      'postalCode': '22314',
#      'cc': 'US',
#      'city': 'Alexandria',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1557 Potomac Greens Dr',
#       'Alexandria, VA 22314',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d108951735',
#       'name': "Women's Store",
#       'pluralName': "Women's Stores",
#       'shortName': "Women's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '581a7b6d5d0a1a56bb13895f',
#     'name': 'Periodontal & Implant Associates of Greater Washington',
#     'location': {'address': '5454 Wisconsin Ave',
#      'lat': 38.96265609,
#      'lng': -77.08703819,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.96265609,
#        'lng': -77.08703819}],
#      'distance': 8708,
#      'postalCode': '20815',
#      'cc': 'US',
#      'city': 'Chevy Chase',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['5454 Wisconsin Ave',
#       'Chevy Chase, MD 20815',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '52cea787498e17417199706e',
#     'name': 'Dr Israel Puterman Implants & Periodontics',
#     'location': {'address': '5454 Wisconsin Ave Ste 1550',
#      'lat': 38.962432,
#      'lng': -77.08741,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.962432,
#        'lng': -77.08741}],
#      'distance': 8703,
#      'postalCode': '20815',
#      'cc': 'US',
#      'city': 'Chevy Chase',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['5454 Wisconsin Ave Ste 1550',
#       'Chevy Chase, MD 20815',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4df8ea37d164d347cc741421',
#     'name': 'Dr Madjid Matin, Periodontics',
#     'location': {'address': '5530 Wisconsin Ave #1110',
#      'lat': 38.965006,
#      'lng': -77.088244,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.965006,
#        'lng': -77.088244}],
#      'distance': 8987,
#      'postalCode': '20815',
#      'cc': 'US',
#      'city': 'Chevy Chase',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['5530 Wisconsin Ave #1110',
#       'Chevy Chase, MD 20815',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4fd0d576e4b0d4dee7d83514',
#     'name': 'Israel Puterman, Implants & Periodontics',
#     'location': {'address': '5454 Wisconsin Ave Ste 1550',
#      'lat': 38.9626187,
#      'lng': -77.0872772,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.9626187,
#        'lng': -77.0872772}],
#      'distance': 8715,
#      'postalCode': '20815',
#      'cc': 'US',
#      'city': 'Chevy Chase',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['5454 Wisconsin Ave Ste 1550',
#       'Chevy Chase, MD 20815',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '53727eb8498e2f4952fe41de',
#     'name': 'David Sarment Periodontics',
#     'location': {'lat': 38.828537866814806,
#      'lng': -77.11071968046963,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.828537866814806,
#        'lng': -77.11071968046963}],
#      'distance': 9799,
#      'cc': 'US',
#      'city': 'Alexandria',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['Alexandria, VA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '57518a9b498e788996802292',
#     'name': 'Precision Periodontics and Implant Dentistry',
#     'location': {'address': '4660 Kenmore Ave',
#      'lat': 38.82824737,
#      'lng': -77.11043359,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.82824737,
#        'lng': -77.11043359},
#       {'label': 'entrance', 'lat': 38.828355, 'lng': -77.110517}],
#      'distance': 9807,
#      'postalCode': '22304',
#      'cc': 'US',
#      'city': 'Alexandria',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['4660 Kenmore Ave',
#       'Alexandria, VA 22304',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '576915007'},
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '52838dfc11d283f75a326ba8',
#     'name': 'periscopeUP',
#     'location': {'address': '7500 Bybrook Lane',
#      'crossStreet': 'Greenvale Street',
#      'lat': 38.9840487031771,
#      'lng': -77.05864191055296,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.9840487031771,
#        'lng': -77.05864191055296}],
#      'distance': 10096,
#      'postalCode': '20815',
#      'cc': 'US',
#      'neighborhood': 'Chevy Chase',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['7500 Bybrook Lane (Greenvale Street)',
#       'Washington, D.C. 20815',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '5e46a162f17d0400076dce38',
#     'name': 'Northern Virginia Periodontics',
#     'location': {'address': '103 W Broad St #601',
#      'lat': 38.8821244,
#      'lng': -77.1721069,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.8821244,
#        'lng': -77.1721069}],
#      'distance': 11830,
#      'postalCode': '22046',
#      'cc': 'US',
#      'city': 'Falls Church',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['103 W Broad St #601',
#       'Falls Church, VA 22046',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4ee4e9b2aa1fd7f754d93bd7',
#     'name': 'Periwinkle',
#     'location': {'address': '160 American Way',
#      'lat': 38.784696000000004,
#      'lng': -77.015348,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.784696000000004,
#        'lng': -77.015348},
#       {'label': 'entrance', 'lat': 38.784486, 'lng': -77.015398}],
#      'distance': 12414,
#      'postalCode': '20745',
#      'cc': 'US',
#      'city': 'Oxon Hill',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['160 American Way',
#       'Oxon Hill, MD 20745',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '56dda900498e4f2a39c5b37f',
#     'name': 'Falls Church Periodontics & Dental Implants',
#     'location': {'address': '313 Park Ave Ste 103',
#      'lat': 38.8853129,
#      'lng': -77.1738077,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.8853129,
#        'lng': -77.1738077}],
#      'distance': 11939,
#      'postalCode': '22046',
#      'cc': 'US',
#      'city': 'Falls Church',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['313 Park Ave Ste 103',
#       'Falls Church, VA 22046',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4eb155c5b63434fc870d8eec',
#     'name': 'Falls Church Chiropractor - Dr. Ted Perih',
#     'location': {'address': '803 W Broad St Ste 240',
#      'lat': 38.88793884430895,
#      'lng': -77.1804045535571,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.88793884430895,
#        'lng': -77.1804045535571},
#       {'label': 'entrance', 'lat': 38.888082, 'lng': -77.1806}],
#      'distance': 12486,
#      'postalCode': '22046',
#      'cc': 'US',
#      'city': 'Falls Church',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['803 W Broad St Ste 240',
#       'Falls Church, VA 22046',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3a',
#       'name': 'Chiropractor',
#       'pluralName': 'Chiropractors',
#       'shortName': 'Chiropractors',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '4d67c1fc5c2ecbff8aa52ce9',
#     'name': 'Peris Companies, Inc.',
#     'location': {'address': '282 N Washington St',
#      'crossStreet': 'at Great Falls St & Lee Hwy',
#      'lat': 38.883763,
#      'lng': -77.16851899999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.883763,
#        'lng': -77.16851899999999},
#       {'label': 'entrance', 'lat': 38.883868, 'lng': -77.168627}],
#      'distance': 11500,
#      'postalCode': '22046',
#      'cc': 'US',
#      'city': 'Falls Church',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['282 N Washington St (at Great Falls St & Lee Hwy)',
#       'Falls Church, VA 22046',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '5bc0d461c0cacb0039acdc88',
#     'name': 'Peri-Peri Original',
#     'location': {'lat': 38.742358,
#      'lng': -77.163409,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.742358,
#        'lng': -77.163409},
#       {'label': 'entrance', 'lat': 38.742318, 'lng': -77.16307}],
#      'distance': 20240,
#      'postalCode': '22315',
#      'cc': 'US',
#      'city': 'Alexandria',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['Alexandria, VA 22315', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1026829',
#      'url': 'https://www.grubhub.com/restaurant/peri-peri-original-6456-old-beulah-st-alexandria/1026829?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1026829',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '5b635806396de0002c81c57f',
#     'name': 'Perimon Insurance Services',
#     'location': {'address': '7115 Leesburg Pike, Ste 311',
#      'lat': 38.894566,
#      'lng': -77.191919,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.894566,
#        'lng': -77.191919}],
#      'distance': 13459,
#      'postalCode': '22043',
#      'cc': 'US',
#      'city': 'Falls Church',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['7115 Leesburg Pike, Ste 311',
#       'Falls Church, VA 22043',
#       'United States']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1f1',
#       'name': 'Insurance Office',
#       'pluralName': 'Insurance Offices',
#       'shortName': 'Insurance Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False},
#    {'id': '5420a495498ef6d4a6acaf35',
#     'name': "Nando's",
#     'location': {'address': '14722 Baltimore Ave',
#      'crossStreet': 'Laurel Town Centre',
#      'lat': 39.0941509402657,
#      'lng': -76.85693048916502,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.0941509402657,
#        'lng': -76.85693048916502},
#       {'label': 'entrance', 'lat': 39.094092, 'lng': -76.856663}],
#      'distance': 27075,
#      'postalCode': '20707',
#      'cc': 'US',
#      'city': 'Laurel',
#      'state': 'MD',
#      'country': 'United States',
#      'formattedAddress': ['14722 Baltimore Ave (Laurel Town Centre)',
#       'Laurel, MD 20707',
#       'United States']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1601139566',
#     'hasPerk': False}]}}

# %%
'There are {} around DMV area.'.format(len(nandos1_results['response']['venues']))
# Out:
# 'There are 50 around DMV area.'

# %%
# assign relevant part of JSON to venues
nandos_venues1 = nandos1_results['response']['venues']

# tranform venues into a dataframe
nandos_dmv_df = json_normalize(nandos_venues1)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in nandos_dmv_df.columns if col.startswith('location.')] + ['id']
dataframe_filtered2 = nandos_dmv_df.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered2['categories'] = dataframe_filtered2.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered2.columns = [column.split('.')[-1] for column in dataframe_filtered2.columns]

dataframe_filtered2 = dataframe_filtered2[dataframe_filtered2['name'].str.contains('Nando\'s')]
dataframe_filtered2.drop(['crossStreet'], axis = 1,  inplace = True)

dataframe_filtered2 = dataframe_filtered2.drop(dataframe_filtered2.index[0])

# %%
nandos_df_final = pd.concat([dataframe_filtered1, dataframe_filtered2], axis = 0)

# %% [markdown]
# - Displays amount of rows and columns in dataframe respectively. The 34 rows show that there are 34 Nando's restaurants in USA, found by Foursquare.

# %%
nandos_df_final.shape
# Out:
# (34, 15)

# %% [markdown]
# - #### Displaying final dataframe with all Nando's locations found in Foursquare data:

# %%
nandos_df_final
# Out:
#                  name             categories                         address  \
# 0   Nando's Peri-Peri  Portuguese Restaurant                   117 E Lake St
# 1   Nando's Peri-Peri  Portuguese Restaurant                227 E Ontario St
# 2   Nando's Peri-Peri  Portuguese Restaurant                 22 S Wabash Ave
# 3   Nando's Peri-Peri  Portuguese Restaurant              1005 S Delano Ct E
# 4   Nando's Peri-Peri  Portuguese Restaurant                523 Oakbrook Ctr
# 5   Nando's Peri-Peri  Portuguese Restaurant                  1447 E 53rd St
# 6   Nando's Peri-Peri  Portuguese Restaurant                    1138 Lake St
# 7   Nando's Peri-Peri  Portuguese Restaurant             1500 N Clybourn Ave
# 8   Nando's Peri-Peri  Portuguese Restaurant            4999 Old Orchard Ctr
# 9   Nando's Peri-Peri  Portuguese Restaurant               6 W Jefferson Ave
# 10            Nando's  Portuguese Restaurant               953 W Randolph St
# 11            Nando's  Portuguese Restaurant             670 W Diversey Pkwy
# 1   Nando's Peri-Peri  Portuguese Restaurant           1800 N Lynn St, # 100
# 2   Nando's Peri-Peri  Portuguese Restaurant         2631 Connecticut Ave NW
# 3   Nando's Peri-Peri  Portuguese Restaurant       300 Tingey St SE, Ste 150
# 4   Nando's Peri-Peri  Portuguese Restaurant  12120 Sunset Hills Rd, Ste 103
# 5   Nando's Peri-Peri  Portuguese Restaurant                224 Boardwalk Pl
# 6   Nando's Peri-Peri  Portuguese Restaurant                     411 H St NE
# 7   Nando's Peri-Peri  Portuguese Restaurant               2987 District Ave
# 8   Nando's Peri-Peri  Portuguese Restaurant        1301 S Joyce St, Ste D10
# 9   Nando's Peri-Peri  Portuguese Restaurant                4401 Wilson Blvd
# 10  Nando's Peri-Peri  Portuguese Restaurant                191 American Way
# 11  Nando's Peri-Peri  Portuguese Restaurant                     702 King St
# 12  Nando's Peri-Peri  Portuguese Restaurant               4839 Bethesda Ave
# 13  Nando's Peri-Peri  Portuguese Restaurant                    922 Rose Ave
# 14  Nando's Peri-Peri  Portuguese Restaurant              7400 Baltimore Ave
# 15  Nando's Peri-Peri  Portuguese Restaurant             2002 Annapolis Mall
# 16  Nando's Peri-Peri  Portuguese Restaurant             11160 Veirs Mill Rd
# 17            Nando's  Portuguese Restaurant                1210 18th Street
# 18            Nando's  Portuguese Restaurant                   819 7th St NW
# 19            Nando's  Portuguese Restaurant           4231 Wisconsin Ave NW
# 21            Nando's  Portuguese Restaurant                924 Ellsworth Dr
# 24            Nando's  Portuguese Restaurant           6500 Springfield Mall
# 49            Nando's  Portuguese Restaurant             14722 Baltimore Ave
#
#     cc            city        country  distance  \
# 0   US         Chicago  United States      1128
# 1   US         Chicago  United States      1993
# 2   US         Chicago  United States       656
# 3   US         Chicago  United States       951
# 4   US       Oak Brook  United States     27316
# 5   US         Chicago  United States      8948
# 6   US        Oak Park  United States     14978
# 7   US         Chicago  United States      4143
# 8   US          Skokie  United States     23120
# 9   US      Naperville  United States     44920
# 10  US         Chicago  United States      2462
# 11  US         Chicago  United States      6629
# 1   US       Arlington  United States      3018
# 2   US      Washington  United States      3542
# 3   US      Washington  United States      3781
# 4   US          Reston  United States     29213
# 5   US    Gaithersburg  United States     28358
# 6   US      Washington  United States      3210
# 7   US         Fairfax  United States     17099
# 8   US       Arlington  United States      4229
# 9   US       Arlington  United States      6868
# 10  US       Oxon Hill  United States     12496
# 11  US      Alexandria  United States     10060
# 12  US        Bethesda  United States     10928
# 13  US  North Bethesda  United States     18688
# 14  US    College Park  United States     12821
# 15  US       Annapolis  United States     43636
# 16  US         Wheaton  United States     15774
# 17  US      Washington  United States      1325
# 18  US      Washington  United States      1402
# 19  US      Washington  United States      6506
# 21  US   Silver Spring  United States     11264
# 24  US     Springfield  United States     18079
# 49  US          Laurel  United States     27075
#
#                                      formattedAddress  \
# 0   [117 E Lake St, Chicago, IL 60601, United States]
# 1   [227 E Ontario St, Chicago, IL 60611, United S...
# 2   [22 S Wabash Ave, Chicago, IL 60603, United St...
# 3   [1005 S Delano Ct E (no), Chicago, IL 60605, U...
# 4   [523 Oakbrook Ctr, Oak Brook, IL 60523, United...
# 5   [1447 E 53rd St, Chicago, IL 60615, United Sta...
# 6   [1138 Lake St, Oak Park, IL 60301, United States]
# 7   [1500 N Clybourn Ave, Chicago, IL 60610, Unite...
# 8   [4999 Old Orchard Ctr, Skokie, IL 60077, Unite...
# 9   [6 W Jefferson Ave, Naperville, IL 60540, Unit...
# 10  [953 W Randolph St (at N Morgan St), Chicago, ...
# 11  [670 W Diversey Pkwy (Clark), Chicago, IL 6061...
# 1   [1800 N Lynn St, # 100, Arlington, VA 22209, U...
# 2   [2631 Connecticut Ave NW, Washington, D.C. 200...
# 3   [300 Tingey St SE, Ste 150 (at 4th St SE), Was...
# 4   [12120 Sunset Hills Rd, Ste 103, Reston, VA 20...
# 5   [224 Boardwalk Pl, Gaithersburg, MD 20878, Uni...
# 6   [411 H St NE (btwn 4th & 5th St NE), Washingto...
# 7   [2987 District Ave, Fairfax, VA 22031, United ...
# 8   [1301 S Joyce St, Ste D10, Arlington, VA 22202...
# 9   [4401 Wilson Blvd (N Glebe Rd), Arlington, VA ...
# 10  [191 American Way (Fleet St), Oxon Hill, MD 20...
# 11  [702 King St (btwn N Washington & N Columbus),...
# 12  [4839 Bethesda Ave, Bethesda, MD 20814, United...
# 13  [922 Rose Ave, North Bethesda, MD 20852, Unite...
# 14  [7400 Baltimore Ave, College Park, MD 20740, U...
# 15  [2002 Annapolis Mall, Annapolis, MD 21401, Uni...
# 16  [11160 Veirs Mill Rd, Wheaton, MD 20902, Unite...
# 17  [1210 18th Street (at Connecticut Ave NW), Was...
# 18  [819 7th St NW (at I St NW), Washington, D.C. ...
# 19  [4231 Wisconsin Ave NW (at Veazey St NW), Wash...
# 21  [924 Ellsworth Dr, Silver Spring, MD 20910, Un...
# 24  [6500 Springfield Mall, Springfield, VA 22150,...
# 49  [14722 Baltimore Ave (Laurel Town Centre), Lau...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 41.88569436185178...  41.885694 -87.624279
# 1   [{'label': 'display', 'lat': 41.89334608148888...  41.893346 -87.621604
# 2   [{'label': 'display', 'lat': 41.88132517058762...  41.881325 -87.626106
# 3   [{'label': 'display', 'lat': 41.86961552058229...  41.869616 -87.632662
# 4   [{'label': 'display', 'lat': 41.85196765881677...  41.851968 -87.952390
# 5   [{'label': 'display', 'lat': 41.79939796688211...  41.799398 -87.589921
# 6   [{'label': 'display', 'lat': 41.88868248371064...  41.888682 -87.804284
# 7   [{'label': 'display', 'lat': 41.90864069497578...  41.908641 -87.647344
# 8   [{'label': 'display', 'lat': 42.06106950200311...  42.061070 -87.750040
# 9   [{'label': 'display', 'lat': 41.77284854418508...  41.772849 -88.148100
# 10  [{'label': 'display', 'lat': 41.88414549439909...  41.884145 -87.651799
# 11  [{'label': 'display', 'lat': 41.93283780905163...  41.932838 -87.646343
# 1   [{'label': 'display', 'lat': 38.89678217419600...  38.896782 -77.071340
# 2   [{'label': 'display', 'lat': 38.92448048565016...  38.924480 -77.051932
# 3   [{'label': 'display', 'lat': 38.87511377862982...  38.875114 -77.001173
# 4   [{'label': 'display', 'lat': 38.95455817310046...  38.954558 -77.365092
# 5   [{'label': 'display', 'lat': 39.11672909294069...  39.116729 -77.197954
# 6   [{'label': 'display', 'lat': 38.90004474497485...  38.900045 -77.000087
# 7   [{'label': 'display', 'lat': 38.86966475388093...  38.869665 -77.231200
# 8   [{'label': 'display', 'lat': 38.86310364957474...  38.863104 -77.063123
# 9   [{'label': 'display', 'lat': 38.8801752129954,...  38.880175 -77.113520
# 10  [{'label': 'display', 'lat': 38.78398459136630...  38.783985 -77.015050
# 11  [{'label': 'display', 'lat': 38.805002, 'lng':...  38.805002 -77.047422
# 12  [{'label': 'display', 'lat': 38.98108594463042...  38.981086 -77.097204
# 13  [{'label': 'display', 'lat': 39.05093418611199...  39.050934 -77.116523
# 14  [{'label': 'display', 'lat': 38.98094897719873...  38.980949 -76.938020
# 15  [{'label': 'display', 'lat': 38.98748974676994...  38.987490 -76.546818
# 16  [{'label': 'display', 'lat': 39.03597342780978...  39.035973 -77.054931
# 17  [{'label': 'display', 'lat': 38.90613554456633...  38.906136 -77.041951
# 18  [{'label': 'display', 'lat': 38.90037043531736...  38.900370 -77.021942
# 19  [{'label': 'display', 'lat': 38.94410045683627...  38.944100 -77.077294
# 21  [{'label': 'display', 'lat': 38.99587221554965...  38.995872 -77.026533
# 24  [{'label': 'display', 'lat': 38.77414253284657...  38.774143 -77.175881
# 49  [{'label': 'display', 'lat': 39.0941509402657,...  39.094151 -76.856930
#
#    neighborhood postalCode state                        id
# 0      The Loop      60601    IL  59aed71ed552c7632d13c4ee
# 1           NaN      60611    IL  57a77b9ccd10b3ef21d62622
# 2           NaN      60603    IL  5652164f498e36174c80c9d5
# 3    South Loop      60605    IL  57916296498e390c2b6789cd
# 4           NaN      60523    IL  582bcbf3b4f96227bc841dd9
# 5     Hyde Park      60615    IL  5879756edebdf66d8d988415
# 6           NaN      60301    IL  5723f8cd498e225a55db86e4
# 7    Near North      60610    IL  56082509498e965f8c47da3c
# 8           NaN      60077    IL  582b45bb0839692c503a3a02
# 9           NaN      60540    IL  56edd744cd10c4efe37e197f
# 10          NaN      60607    IL  55578ce6498e5067c3f53ffd
# 11          NaN      60614    IL  558708ac498ebcd400e0e291
# 1           NaN      22209    VA  5aa6ab5c95da0c6a54a0162e
# 2           NaN      20008  D.C.  57c61813498e250533871440
# 3           NaN      20003  D.C.  520a756911d20ef0a74a329b
# 4           NaN      20190    VA  5a0dcecaa5a3153b498f6353
# 5           NaN      20878    MD  4e5bbbbf813034cf45e4500d
# 6           NaN      20002  D.C.  56d1deb7cd10b98f4cbb3c01
# 7           NaN      22031    VA  57125a2a498e20f5ec604732
# 8           NaN      22202    VA  4f7d3888e4b0f6ec00d81eae
# 9           NaN      22203    VA  57ddadef498e917deca47fe7
# 10          NaN      20745    MD  4e8b424e93ad2e858aba438a
# 11          NaN      22314    VA  50856fc0e4b0fedebfa0c98a
# 12          NaN      20814    MD  4eaeeca01081289f77b48f81
# 13          NaN      20852    MD  5ade087f345cbe1ecb452c2b
# 14          NaN      20740    MD  562e4dd4498e6542cc35b284
# 15          NaN      21401    MD  56705d14498efccf86b5645c
# 16          NaN      20902    MD  5679ded7498ecd39eddb0256
# 17          NaN      20001  D.C.  4ac6d815f964a52072b620e3
# 18          NaN      20001  D.C.  4a4eb693f964a520f4ae1fe3
# 19          NaN      20016  D.C.  536c11ed498e87758c93ae2c
# 21          NaN      20910    MD  4c8ece09d2aea0933fa1d169
# 24          NaN      22150    VA  546788cf498e655a9214e831
# 49          NaN      20707    MD  5420a495498ef6d4a6acaf35

# %% [markdown]
# ### 2.4 Collecting information regarding all South African visas processed between 2001 and 2019:

# %% [markdown]
# - I downloaded the all visa pdf files from www.travel.state.gov and then converted it to csv format for ease of use to make it simpler to put into the notebook
# - I will also add a total column to the final dataframes for simplicity when building the model
# *Note:* I had to import the csv file by adding data option and inserting the file that included the codes below as well as importing the libraries needed above

# %% [markdown]
# - Immigrant visa data being extracted:

# %%
# The code was removed by Watson Studio for sharing.

# %%
body = client_a65cf93f5b9043d3acc137cab7f57621.get_object(Bucket='courseracapstoneproject-donotdelete-pr-isypujnflig1pw',Key='Immigrant1.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

immigrant_visa_df1 = pd.read_csv(body)
immigrant_visa_df1 = immigrant_visa_df1[5:33]
immigrant_visa_df1.rename(columns = {'Unnamed: 0': 'Nationality', 'Unnamed: 1': '2001', 'Unnamed: 2': '2002', 'Table XV': '2003', 'Unnamed: 4': '2004', 'Unnamed: 5': '2005', 'Unnamed: 6': '2006', 'Unnamed: 7': '2007', 'Unnamed: 8': '2008', 'Unnamed: 9': '2009', 'Unnamed: 10': '2010'}, inplace = True)
immigrant_visa_df1.drop(['2010'], axis = 1, inplace = True)

# %%
body1 = client_a65cf93f5b9043d3acc137cab7f57621.get_object(Bucket='courseracapstoneproject-donotdelete-pr-isypujnflig1pw',Key='Immigrant2.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body1, "__iter__"): body1.__iter__ = types.MethodType( __iter__, body1 )

immigrant_visa_df2 = pd.read_csv(body1)
immigrant_visa_df2 = immigrant_visa_df2[6:36]
immigrant_visa_df2.rename(columns = {'Unnamed: 0': 'Nationality', 'FY 2019 data are preliminary and subject to change.': '2010', 'Unnamed: 2': '2011', 'Unnamed: 3': '2012', 'Unnamed: 4': '2013', 'Unnamed: 5': '2014', 'Unnamed: 6': '2015', 'Unnamed: 7': '2016', 'Unnamed: 8': '2017', 'Unnamed: 9': '2018', 'Unnamed: 10': '2019'}, inplace = True)

# %% [markdown]
# - Joins Immigrant visa tables together to form one dataframe:

# %%
imm_visa_df = pd.merge(immigrant_visa_df1, immigrant_visa_df2, on='Nationality')
imm_visa_df = imm_visa_df[imm_visa_df['Nationality'] == 'South Africa, Johannesburg']#filter data to only show South Africa
imm_visa_df.replace(',','', inplace = True) 
imm_visa_df.replace('South Africa, Johannesburg', 'South African', inplace = True)

# %% [markdown]
# - Nonimmigrant visa data being extracted:

# %%
body2 = client_a65cf93f5b9043d3acc137cab7f57621.get_object(Bucket='courseracapstoneproject-donotdelete-pr-isypujnflig1pw',Key='Nonimmigrant1 (2).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body2, "__iter__"): body2.__iter__ = types.MethodType( __iter__, body2 )

nonimmigrant_visa_df1 = pd.read_csv(body2)
nonimmigrant_visa_df1 = nonimmigrant_visa_df1[5:64]
nonimmigrant_visa_df1.rename(columns = {'Unnamed: 0': 'Nationality', 'Unnamed: 1': '2001', 'Unnamed: 2': '2002', 'Table XVIII': '2003', 'Unnamed: 4': '2004', 'Unnamed: 5': '2005', 'Unnamed: 6': '2006', 'Unnamed: 7': '2007', 'Unnamed: 8': '2008', 'Unnamed: 9': '2009', 'Unnamed: 10': '2010'}, inplace = True)
nonimmigrant_visa_df1.drop([36,  37, 38, 39, 40], axis = 0, inplace = True)
nonimmigrant_visa_df1.drop(['2010'], axis = 1, inplace = True)

# %%
body3 = client_a65cf93f5b9043d3acc137cab7f57621.get_object(Bucket='courseracapstoneproject-donotdelete-pr-isypujnflig1pw',Key='Nonimmigrant2 (2).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body3, "__iter__"): body3.__iter__ = types.MethodType( __iter__, body3 )

nonimmigrant_visa_df2 = pd.read_csv(body3)
nonimmigrant_visa_df2 = nonimmigrant_visa_df2[6:67]
nonimmigrant_visa_df2.rename(columns = {'Unnamed: 0': 'Nationality', 'Unnamed: 1': '2010', 'FY 2019 data are preliminary and subject to change.': '2011', 'Unnamed: 3': '2012', 'Unnamed: 4': '2013', 'Unnamed: 5': '2014', 'Unnamed: 6': '2015', 'Unnamed: 7': '2016', 'Unnamed: 8': '2017', 'Unnamed: 9': '2018', 'Unnamed: 10': '2019'}, inplace = True)
nonimmigrant_visa_df2.drop([37, 38, 39, 40, 41, 42], axis = 0, inplace = True)

# %% [markdown]
# - Joins nonimmgrant visa tables together to form one dataframe:

# %%
nonimm_visa_df = pd.merge(nonimmigrant_visa_df1, nonimmigrant_visa_df2, on='Nationality')
nonimm_visa_df = nonimm_visa_df[nonimm_visa_df['Nationality'] == 'South Africa']#filter data to only show South Africa
nonimm_visa_df.replace(',','', inplace = True) 
nonimm_visa_df.replace('South Africa', 'South African', inplace = True)

# %% [markdown]
# Join the nonimmigrant and immigrant dataframes into one dataframe, replace string number valeus as integers and total all the columns to help with the data analysis section:

# %%
visa_df = pd.concat([nonimm_visa_df, imm_visa_df])
visa_df['2001'] = visa_df['2001'].str.replace(",","").astype(int)
visa_df['2002'] = visa_df['2002'].str.replace(",","").astype(int)
visa_df['2003'] = visa_df['2003'].str.replace(",","").astype(int)
visa_df['2004'] = visa_df['2004'].str.replace(",","").astype(int)
visa_df['2005'] = visa_df['2005'].str.replace(",","").astype(int)
visa_df['2006'] = visa_df['2006'].str.replace(",","").astype(int)
visa_df['2007'] = visa_df['2007'].str.replace(",","").astype(int)
visa_df['2008'] = visa_df['2008'].str.replace(",","").astype(int)
visa_df['2009'] = visa_df['2009'].str.replace(",","").astype(int)
visa_df['2010'] = visa_df['2010'].str.replace(",","").astype(int)
visa_df['2011'] = visa_df['2011'].str.replace(",","").astype(int)
visa_df['2012'] = visa_df['2012'].str.replace(",","").astype(int)
visa_df['2013'] = visa_df['2013'].str.replace(",","").astype(int)
visa_df['2014'] = visa_df['2014'].str.replace(",","").astype(int)
visa_df['2015'] = visa_df['2015'].str.replace(",","").astype(int)
visa_df['2016'] = visa_df['2016'].str.replace(",","").astype(int)
visa_df['2017'] = visa_df['2017'].str.replace(",","").astype(int)
visa_df['2018'] = visa_df['2018'].str.replace(",","").astype(int)
visa_df['2019'] = visa_df['2019'].str.replace(",","").astype(int)
visa_df = visa_df.append(visa_df.sum(numeric_only=True), ignore_index=True)
visa_df = visa_df.replace(np.nan, 'Total South African Visas', regex=True)

# %% [markdown]
# ### 2.5 Collect data to determine which neighborhood is best to open the Nandos restaurant in NYC:

# %% [markdown]
# #### 2.5.1 Restaurants in New York City
#
# - I will use this data to isolate the neighbourhoods I am looking at closer at in order to find the least restaurant-dense area to open my restaurant

# %%
body4 = client_a65cf93f5b9043d3acc137cab7f57621.get_object(Bucket='courseracapstoneproject-donotdelete-pr-isypujnflig1pw',Key='Restaurants__rolled_up_.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body4, "__iter__"): body4.__iter__ = types.MethodType( __iter__, body4 )

nyc_res_df = pd.read_csv(body4)
nyc_res_df.drop(['CAMIS'], axis = 1, inplace = True)
nyc_res_df.drop(['BUILDING'], axis = 1, inplace = True)
br_res_df = nyc_res_df[nyc_res_df.BORO.str.contains('Brooklyn')]

# %% [markdown]
# #### 2.5.2 Determining immigration to America from all African countries.
#
# - I used tables extracted from www.wikipedia.com and www.baruch.cuny.edu

# %%
immigration_df = pd.read_html("https://en.wikipedia.org/wiki/African_immigration_to_the_United_States")[1]

# %% [markdown]
# - Removing percentage columns given that there is no added data:

# %%
immigration_df = immigration_df[['Ancestry', '2000', '2010']]

# %% [markdown]
# - Columns are converted to lists:

# %%
type(immigration_df.columns.tolist())
type(immigration_df.index.tolist())
# Out:
# list

# %% [markdown]
# #### 2.5.4 Determine the African immigration population distributed between main cities in USA:
#
# - I used webscraping to get data from tables from https://en.wikipedia.org/wiki/African_immigration_to_the_United_States

# %%
city_immigration_df = pd.read_html('https://en.wikipedia.org/wiki/African_immigration_to_the_United_States')[2]

# %% [markdown]
# #### 2.5.5 Determine the amount of South Africans in America for the years 2010 to 2017:
#
# - I used webscraping to get data from tables from https://en.wikipedia.org/wiki/South_African_Americans

# %%
sa_in_usa_df = pd.read_html('https://en.wikipedia.org/wiki/South_African_Americans')[2]

# %%
type(sa_in_usa_df.columns.tolist())
type(sa_in_usa_df.index.tolist())
# Out:
# list

# %% [markdown]
# #### 2.5.6 Determine distribution of Africans into NYC boroughs for the year 2019:
#
# - I used webscraping to get data from tables from https://www.baruch.cuny.edu/nycdata/population-geography/foreign-birthcountry.htm

# %%
borough_distr_df = pd.read_html('https://www.baruch.cuny.edu/nycdata/population-geography/foreign-birthcountry.htm')[0]

# %%
type(borough_distr_df.columns.tolist())
type(borough_distr_df.index.tolist())
# Out:
# list

# %%
borough_distr_df = borough_distr_df[[1, 2, 3, 4, 5, 6, 7]]

# %% [markdown]
# For simplicity, I will clean out the column headings:

# %%
borough_distr_df.rename(columns = {1: 'Country of Birth', 
                                   2: 'Total NYC', 
                                   3: 'Bronx', 
                                   4: 'Brooklyn - Kings', 
                                   5: 'Manhattan - New York', 
                                   6: 'Queens', 
                                   7: 'Staten Island - Richmond'}, inplace = True)

# %%
borough_distr_df = borough_distr_df[4:67]

# %% [markdown]
# Filter dataframe to only display African immigration information:

# %%
borough_final_df = borough_distr_df[borough_distr_df['Country of Birth'].str.contains('Africa')]

# %% [markdown]
# ***
# ## 3. METHODOLOGY: <a name="methodology"></a>

# %% [markdown]
# - I used different tables of data extracted to ensure I can properly predict how many South Africans would reside in New York City
# - Some tables might be left obselete in the conclusion

# %% [markdown]
# #### 3.1 Using analysis to determine the success of a Nando's being opened in New York City:

# %%
immigration_df = immigration_df[immigration_df['Ancestry'] == 'South African']
immigration_df
# Out:
#          Ancestry        2000        2010
# 25  South African  44,991[16]  57,491[17]

# %% [markdown]
# #### 3.2 Using exploratory analysis to determine how many South Africans will reside in NYC in 2020:

# %%
sa_in_usa_df.rename(columns = {'Number': 'Amount of South Africans'}, inplace = True)

# %%
sa_in_usa_df
# Out:
#    Year  Amount of South Africans
# 0  2010                     77985
# 1  2011                     87699
# 2  2012                     85528
# 3  2013                     95191
# 4  2014                     92218
# 5  2015                     94141
# 6  2016                    104889
# 7  2017                    111720

# %%
sns.regplot(x="Year", y="Amount of South Africans", data=sa_in_usa_df)
plt.ylim(0,)
plt.title('Linear Regression of the Amount of South Africans Residing in USA from 2010 to 2017', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Linear Regression of the Amount of South Africans Residing in USA from 2010 to 2017')

# %%
lr1 = LinearRegression()
lr1

X1 = sa_in_usa_df[['Year']]
Y1 = sa_in_usa_df['Amount of South Africans']

lr1.fit(X1,Y1)

Yhat1=lr1.predict(X1)
Yhat1[0:10] 

a1 = lr1.intercept_
b1 = lr1.coef_

pearson_coef1, p_value1 = stats.pearsonr(sa_in_usa_df['Year'], sa_in_usa_df['Amount of South Africans'])
print('The x-intercept is: ', int(a1), 
      '\nThe coeffiecient is:' , int(b1), 
      '\nThe Pearson Correlation Coefficient is', pearson_coef1, 
      '\nThe P-value of P =', p_value1)
# Out:
# The x-intercept is:  -8175125
# The coeffiecient is: 4106
# The Pearson Correlation Coefficient is 0.9384534428165742
# The P-value of P = 0.0005562698212109472

# %% [markdown]
# - The correlation between the data is very high therefore the linear regression is the best fit for this model
# - The P-value is less than 0.001 which is a great indicator for the given regression
# - To predict the amount of South Africans living in USA in 2020, I will need to use the equation Yhat = a + b x (x) ie Amount of SA immigrants in 2020 = -8175125 + 4106 x (x)

# %%
imm_2020_estimate1 = a1 + b1*2020
print('The amount of South African\'s residing in New York in 2020 is predicted to be: ', int(imm_2020_estimate1))
# Out:
# The amount of South African's residing in New York in 2020 is predicted to be:  120364

# %%
width = 8
height = 6
plt.figure(figsize=(width, height))
plt.title('Residual Plot Showing The Amount of South Africans Residing in USA from 2010 to 2017', fontsize = 14)
sns.residplot(sa_in_usa_df['Year'], sa_in_usa_df['Amount of South Africans'])
plt.show()

# %% [markdown]
# - The points in the residual plot above are randomly spread out around the x-axis
# - The variance is constant making the  linear model is a good fit for this data

# %%
#set up train-test split of data

x_train1, x_test1, y_train1, y_test1 = train_test_split(sa_in_usa_df[['Year']], 
                                                        sa_in_usa_df['Amount of South Africans'], 
                                                        test_size = 0.15, 
                                                        random_state = 1)
print('The number of test samples: ', x_test1.shape[0])
print('The number of training samples: ', x_train1.shape[0])
# Out:
# The number of test samples:  2
# The number of training samples:  6

# %%
Rcross1 = cross_val_score(lr1, sa_in_usa_df[['Year']], sa_in_usa_df['Amount of South Africans'], cv = 4)
print('The cross valuation Score\'s mean is: ', Rcross1.mean())
print('The cross valuation Score\'s standard deviation is: ',Rcross1.std())
# Out:
# The cross valuation Score's mean is:  -12.840375125376966
# The cross valuation Score's standard deviation is:  20.217012636361112

# %%
regr = linear_model.LinearRegression()

test_x1 = np.asanyarray(sa_in_usa_df[['Year']])
test_y1 = np.asanyarray(sa_in_usa_df['Amount of South Africans'])
regr.fit(test_x1, test_y1)
test_yhat1 = regr.predict(test_x1)

print('EVALUATION METRICS:')
print('Mean Absolute Error: ', np.mean(np.absolute(test_yhat1 - test_y1)))
print('Mean Squared Error: ', np.mean((test_yhat1 - test_y1)**2))
print('R2-Score: ', r2_score(test_yhat1, test_y1))
# Out:
# EVALUATION METRICS:
# Mean Absolute Error:  3123.366071428638
# Mean Squared Error:  11994286.066964373
# R2-Score:  0.8645329494956187

# %%
visa_df
# Out:
#                  Nationality     2001     2002     2003     2004     2005  \
# 0              South African  66541.0  49805.0  51347.0  56634.0  61063.0
# 1              South African   1243.0    971.0   1005.0    740.0    781.0
# 2  Total South African Visas  67784.0  50776.0  52352.0  57374.0  61844.0
#
#       2006     2007     2008     2009     2010     2011     2012     2013  \
# 0  57767.0  58357.0  61801.0  49960.0  51052.0  60152.0  62516.0  59038.0
# 1    796.0    594.0    694.0    868.0    868.0    930.0    841.0    921.0
# 2  58563.0  58951.0  62495.0  50828.0  51920.0  61082.0  63357.0  59959.0
#
#       2014     2015     2016     2017     2018     2019
# 0  60238.0  61997.0  61273.0  61839.0  68950.0  66331.0
# 1    901.0   1006.0   1123.0   1203.0   1174.0   1043.0
# 2  61139.0  63003.0  62396.0  63042.0  70124.0  67374.0

# %%
visa_df.rename(columns = {'Nationality': 'Year'}, inplace = True)
visa_df_t = visa_df.transpose()
visa_df_t.rename(columns = {2:'Total South African Visas'}, inplace = True)
visa_df_t['Year'] = ['', 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
visa_df_t = visa_df_t.iloc[1:]
visa_df_t = visa_df_t[['Total South African Visas', 'Year']]

# %% [markdown]
# - I will only be working with the total column for the exploratory data analysis of the visas issued to predict the 2020 visas issued

# %%
X2 = visa_df_t[['Year']].values
Y2 = visa_df_t['Total South African Visas'].values

# %%
# creating pipeline and fitting it on data
Input=[('polynomial',PolynomialFeatures(degree=2)),('modal',LinearRegression())]
pipe=Pipeline(Input)
pipe.fit(X2.reshape(-1,1),Y2.reshape(-1,1))
# Out:
# Pipeline(memory=None,
#      steps=[('polynomial', PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)), ('modal', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False))])

# %%
y_pred=lr1.predict(X2.reshape(-1,1))
poly_pred=pipe.predict(X2.reshape(-1,1))
#sorting predicted values with respect to predictor
sorted_zip = sorted(zip(X2,poly_pred))
x_poly, poly_pred = zip(*sorted_zip)
#plotting predictions
plt.figure(figsize=(10,6))
plt.scatter(X2, Y2,s=15)
plt.plot(X2,y_pred,color='r',label='Linear Regression')
plt.plot(x_poly,poly_pred,color='g',label='Polynomial Regression')
plt.title('Chart Comparing the Best Fit for South African Visas Issued from 2001 to 2019\n', fontsize = 20)
plt.xlabel('Year',fontsize=16)
plt.ylabel('Total South African Visas',fontsize=16)
x_ticks = np.arange(2000, 2020, 2)
plt.xticks(x_ticks)
plt.legend()
plt.show()

# %% [markdown]
# - Polynomial regression provides a much better fit for the data

# %%
#set up train-test split of data

x_train2, x_test2, y_train2, y_test2 = train_test_split(visa_df_t[['Year']], 
                                                        visa_df_t['Total South African Visas'], 
                                                        test_size = 0.2, random_state = 1)
print('The number of test samples: ', x_test2.shape[0])
print('The number of training samples: ', x_train2.shape[0])
# Out:
# The number of test samples:  4
# The number of training samples:  15

# %% [markdown]
# - looking at the polynomial function formed on the chart in green, it can be seen to resemble a parabola
# - the equation of a parabola is y = a(x-p)^2 + q where a is the gradient and (p, q) are the coordinates of the turning point (minimum value)
# - using this information I will calculate the equation in order to predict the total visas issued for 2020 given the data set for 2001 until 2019

# %%
print('The minimum amount of South African visas issued during the period 2001 to 2019 is: ', visa_df_t['Total South African Visas'].min())
# Out:
# The minimum amount of South African visas issued during the period 2001 to 2019 is:  50776.0

# %% [markdown]
# - This given value is for the year 2002
# - The turning point will be (2002, 50777)
# - By substituting any point from the data into the parabola equation, I can work out the gradient of it ie a = (y-q)/(x-p)^2
# - I will use the point (2018, 70124)

# %%
a = (70124-50777)//((2018-2002)**2)
print('The gradient a for the parabola regression is: ', a)
print('The equation for the line parabola is: Yhat = 75(x-2002)^2 + 50776')
# Out:
# The gradient a for the parabola regression is:  75
# The equation for the line parabola is: Yhat = 75(x-2002)^2 + 50776

# %%
y_2020 = 75*((2020-2002)**2) + 50776
print('The predicted amount of South African visas to be issued in 2020 is: ', y_2020)
# Out:
# The predicted amount of South African visas to be issued in 2020 is:  75076

# %%
pearson_coef2, p_value2 = stats.pearsonr(visa_df_t['Year'], visa_df_t['Total South African Visas'])
print('\nThe Pearson Correlation Coefficient is', pearson_coef2, 
      '\nThe P-value of P =', p_value2)
# Out:
# The Pearson Correlation Coefficient is 0.505166687139397
# The P-value of P = 0.027371269229226912

# %% [markdown]
# - The P-value is low enough to say that there is a 2% chance of finding a difference as large as the study given the hypothesis is found true
# - The Pearson Correlation Coefficient shows the correlation is moderately positive but not strong enough

# %%
from sklearn.model_selection import cross_val_score

Rcross2 = cross_val_score(lr1, visa_df_t[['Year']], visa_df_t['Total South African Visas'], cv = 4)
print('The cross valuation Score\'s mean is: ', Rcross2.mean())
print('The cross valuation Score\'s standard deviation is: ',Rcross2.std())
# Out:
# The cross valuation Score's mean is:  -0.945590224860138
# The cross valuation Score's standard deviation is:  0.7080332522061661

# %% [markdown]
# - The standard deviation is lower than 1 which shows that there is little variance possible in the data

# %%
from sklearn.metrics import r2_score
from sklearn import linear_model

regr2 = linear_model.LinearRegression()

test_x2 = np.asanyarray(visa_df_t[['Year']])
test_y2 = np.asanyarray(visa_df_t['Total South African Visas'])
regr2.fit(test_x2, test_y2)
test_yhat2 = regr2.predict(test_x2)

print('EVALUATION METRICS:')
print('Mean Absolute Error: ', np.mean(np.absolute(test_yhat2 - test_y2)))
print('Mean Squared Error: ', np.mean((test_yhat2 - test_y2)**2))
print('R2-Score: ', r2_score(test_yhat2, test_y2))
# Out:
# EVALUATION METRICS:
# Mean Absolute Error:  3309.4936288088425
# Mean Squared Error:  22222068.30941816
# R2-Score:  -1.9185969203612259

# %% [markdown]
# #### 3.3 Dataframe showing distribution of Africans into America's biggest cities:

# %%
city_immigration_df
# Out:
#           Metropolitan area  African population  % of total metro population
# 0  Washington, DC, MD-VA-WV              171000                          2.9
# 1  Minneapolis-St. Paul, MN               70100                          1.3
# 2               Atlanta, GA               70100                          1.3
# 3             Boston, MA-NH               61600                          1.3
# 4        Baltimore Area, MD               33100                          1.2
# 5              New York, NY              223000                          1.1
# 6     Dallas–Fort Worth, TX               64300                          0.9
# 7               Houston, TX               56100                          0.9
# 8  Greater Los Angeles Area               68100                          0.5
# 9    San Francisco Bay Area               24500                          0.5

# %% [markdown]
# - The dataframe and pie chart above acknowledges that New York City contains the highest number of Africans residing in the city (26.5% as of 2010 census), than any other city in USA

# %% [markdown]
# #### 3.4 Dataframe showing distribution of Africans residing in New York City:

# %%
borough_final_df
# Out:
#               Country of Birth Total NYC  Bronx Brooklyn - Kings  \
# 42                      Africa    148695  57650            34605
# 43              Eastern Africa     10620   1304             1414
# 44             Northern Africa     28393   1548            12885
# 45              Western Africa     92344  49993            16309
# 46  Middle and Southern Africa      7201   1672             1575
# 47               Africa n.e.c.     10137   3133             2422
#
#    Manhattan - New York Queens Staten Island - Richmond
# 42                23243  23722                     9475
# 43                 3441   4307                      154
# 44                 3447   6959                     3554
# 45                11937   9921                     4184
# 46                 2707   1016                      231
# 47                 1711   1519                     1352

# %% [markdown]
# - Using the above data frame, the borough that contains the most Africans residing in NYC is the Bronx
# - However, the Bronx is not at a central location to the city and Long Island so I will choose the second-largest African populated area which is Brooklyn
# - I will use the information to explore neighbourhoods in Brooklyn with the most prosperity for a Nando's to be opened according to the amount of Africans in the area
# - Looking specifically at where South Africans would be situated - Manhattan would be the best location
# - Looking at a Brooklyn location close to manhattan would be best
# - Reading from the web source www.https://www.bkmag.com/2015/12/22/the-best-food-neighborhoods-in-brooklyn-ranked/ , the top 5 restaurant neighbourhoods to consider is Bushwick, Crown Heights, Bed-Stuy, Greenpoint and Cobble Hill-Carroll Gardens

# %%
body4 = client_a65cf93f5b9043d3acc137cab7f57621.get_object(Bucket='courseracapstoneproject-donotdelete-pr-isypujnflig1pw',Key='nynta.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body4, "__iter__"): body4.__iter__ = types.MethodType( __iter__, body4 )

new_york_df = pd.read_csv(body4)
new_york_df = new_york_df[new_york_df['BoroName'] == 'Brooklyn']
new_york_df.drop(['Shape_Leng', 'Shape_Area', 'NTACode', 'BoroCode', 'CountyFIPS'], axis = 1,  inplace = True)
bushwick_df = new_york_df[new_york_df.NTAName.str.contains('Bushwick')]
crown_heights_df = new_york_df[new_york_df.NTAName.str.contains('Crown Heights')]
bed_df = new_york_df[new_york_df.NTAName.str.contains('Bedford')]
stuy_df = new_york_df[new_york_df.NTAName.str.contains('Stuy')]
greenpoint_df = new_york_df[new_york_df.NTAName.str.contains('Greenpoint')]
cobble_df = new_york_df[new_york_df.NTAName.str.contains('Cobble')]
carroll_df = new_york_df[new_york_df.NTAName.str.contains('Carroll')]
top_neighbourhoods = pd.concat([bushwick_df, crown_heights_df, bed_df, stuy_df, greenpoint_df, cobble_df, carroll_df], axis = 0)
#turn series into string
top_neighbourhoods['the_geom'].to_string()
top_neighbourhoods['the_geom'].replace('MULTIPOLYGON', '', inplace = True)
print('The amount of restaurant\'s in Bushwick: ', bushwick_df.shape[0], 
      '\nThe amount of restaurant\'s in Crown Heights: ', crown_heights_df.shape[0], 
      '\nThe amount of restaurant\'s in Bed-Stuy: ', bed_df.shape[0] + stuy_df.shape[0], 
      '\nThe amount of restaurant\'s in Greenpoint: ', greenpoint_df.shape[0], 
      '\nThe amount of restaurant\'s in Cobble Hill Carroll-Gardens: ', cobble_df.shape[0] + carroll_df.shape[0])
# Out:
# The amount of restaurant's in Bushwick:  2
# The amount of restaurant's in Crown Heights:  2
# The amount of restaurant's in Bed-Stuy:  2
# The amount of restaurant's in Greenpoint:  1
# The amount of restaurant's in Cobble Hill Carroll-Gardens:  2

# %% [markdown]
# - The neighbourhood with the least competition would be Greenpoint giving the least amount of restaurants
# ***

# %% [markdown]
# ***
# ## 4. RESULTS: <a name="results"></a>

# %%
colours_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink', 'red', 'grey', 'blue', 'orange']
explode_list = [0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0]
city_immigration_df['African population'].plot(kind = 'pie', 
                                               figsize = [10, 6], 
                                               autopct = '%1.1f%%', 
                                               startangle = 90, 
                                               shadow = True, 
                                               labels = None, 
                                               pctdistance = 1.12, 
                                               colors = colours_list, 
                                               explode = explode_list)
plt.title('Pie Chart Illustrating Distribution of the African Population in US cities\n', fontsize = 18)
plt.axis('equal')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# - This provides recommendation that a Nando's restaurant should be opened in the NYC area

# %% [markdown]
# #### Map of New York City Highlighting Greenpoint:

# %%
address = 'New York, NY'

geolocator = Nominatim(user_agent="new_york_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinate of New York are {}, {}.'.format(latitude, longitude))

# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
folium.CircleMarker(
        [40.7305, -73.9515],
        radius=15,
        popup='Greenpoint',
        color='darkgreen',
        fill=True,
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# The geographical coordinate of New York are 40.7127281, -74.0060152.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ***

# %% [markdown]
# ***
# ## 5. DISCUSSION: <a name="discussion"></a>

# %% [markdown]
# #### 5.1 Recommendations:
# 5.1.1 With foursquare, there was a margin of error given that there are 42 nandos locations surrounding Chicago and DMV areas. I would need to individually inspect the locations and use the exact location to find the missing restaurant location data needed.
# 5.1.2 Nandos is listed as  portuguese restaurant so I had to type in 'Nando's Peri Peri'into the search to ensure the correct venues were selected. Foursquare did not respond to my call for the specific address used to locate the 8 restaurants not included in the data. Next time, I could use a different way to obtain the restaurants information - I could have added the data directly into the dataframe from the Nando's restaurant website.
# 5.1.3 More research by means of market surveys would provide better understanding about how current New York City situated South Africans (and citizens) would feel about the restaurant opening up.
#
# #### 5.2 Considerations
# 5.2.1 Given the current COVID-19 situation happening, the model will definitely be flawed.
# 5.2.2 More South Africans would be staying for longer periods with no flights to leave, therefore the data will need to be adjusted next year.
# 5.2.3 Nando's is takeaway and dine-in, personally my family in South Africa would always use it for takeaways - this makes it accessible for social distancing standards too.
# 5.2.4 An increasing amount of people are making use of takeaway and/or delivery for food and for families that have no time to cook and cannot shop, good quality food is always considered valuable to have in all areas.
# 5.2.5 My project is not based how successful Nando's is as a restaurant in USA, but how much demand there will be for it to open in a heavily 'South African populated' populated area and where it should be place in NYC.
#
# ***

# %% [markdown]
# ***
# ## 6. CONCLUSION: <a name="conclusion"></a>
#
# Nando's Peri Peri is a good investment into New York City's restaurant industry given the increasing amount of South Africans residing in New York City. It has been shown that the amount of Africans overall in America will be increasing too, this include permanent residents and visiting Africans with a nonimmigrant or immigrant visa. There are a lot of factors to consider in this analysis. It is also a personal problem I have faced during my stay in the United States and I know that once endorsed right, it will succeed. The data and charts illustrate its viability of success within New York. The best neighbourhood is within Brooklyn at Greenpoint which has great variety but also less competition from other restaurants in its area. Brooklyn remains close enough to Manhattan as well as Long Island so it poses to be a more central location for any visitors or residents. Visitors to New York will be able to have the search for South African restaurants near by and the Nando's will be eligible to pop up and attract travelers.
# ***
